// %%
import * as tslab from "tslab";
import { readFileSync } from "fs";

const css = readFileSync("../style.css", "utf-8");
tslab.display.html(`<style>${css}</style>`);
// Out:
// <style><link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
// <link href='http://fonts.googleapis.com/css?family=Arvo:400,700,400italic' rel='stylesheet' type='text/css'>
// <link href='http://fonts.googleapis.com/css?family=PT+Mono' rel='stylesheet' type='text/css'>
// <link href='http://fonts.googleapis.com/css?family=Shadows+Into+Light' rel='stylesheet' type='text/css'>
// <link href='http://fonts.googleapis.com/css?family=Philosopher:400,700,400italic,700italic' rel='stylesheet' type='text/css'>
// <link href="http://fonts.googleapis.com/css?family=Sacramento" rel="stylesheet" type="text/css">
//
// <style>
//
// @font-face {
//     font-family: "Computer Modern";
//     src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
// }
//
// .container { width: 100% }
//
// /* Formatting for header cells */
// .text_cell_render h1 {
//     font-family: 'Philosopher', sans-serif;
//     font-weight: 400;
//     font-size: 2.2em;
//     line-height: 100%;
//     color: rgb(0, 80, 120);
//     margin-bottom: 0.1em;
//     margin-top: 0.1em;
//     display: block;
// }
// .text_cell_render h2 {
//     font-family: 'Philosopher', serif;
//     font-weight: 400;
//     font-size: 1.9em;
//     line-height: 100%;
//     color: rgb(200,100,0);
//     margin-bottom: 0.1em;
//     margin-top: 0.1em;
//     display: block;
// }
//
// .text_cell_render h3 {
//     font-family: 'Philosopher', serif;
//     margin-top:12px;
//     margin-bottom: 3px;
//     font-style: italic;
//     color: rgb(94,127,192);
// }
//
// .text_cell_render h4 {
//     font-family: 'Philosopher', serif;
// }
//
// .text_cell_render h5 {
//     font-family: 'Alegreya Sans', sans-serif;
//     font-weight: 300;
//     font-size: 16pt;
//     color: grey;
//     font-style: italic;
//     margin-bottom: .1em;
//     margin-top: 0.1em;
//     display: block;
// }
//
// .text_cell_render h6 {
//     font-family: 'PT Mono', sans-serif;
//     font-weight: 300;
//     font-size: 10pt;
//     color: grey;
//     margin-bottom: 1px;
//     margin-top: 1px;
// }
//
// .text_cell_render em {
//     font-family: 'Philosopher', sans-serif;
//     color:        blue;
//     background-color: rgb(255,220,180);
//     font-size:    110%;
//     margin-left:   2px;
//     margin-right:  2px;
//     font-weight:   100;
// }
//
// .text_cell_render b {
//     color:            rgb(255,195,195);
//     background-color: rgb(0,0,0);
//     font-size:    110%;
//     margin-left:   2px;
//     margin-right:  2px;
//     font-weight:   650;
// }
//
// .text_cell_render u {
//     color:            blue;
//     font-size:    110%;
//     margin-left:   2px;
//     margin-right:  2px;
//     font-weight:   650;
// }
//
// .text_cell_render tt {
//     font-size:    120%;
//     margin-left:   2px;
//     margin-right:  2px;
//     font-weight:   150;
// }
//
// .Codemirror {
//     font-family: "PT Mono";
//     font-size: 100%;
// }
//
// #fancy {
//     font-family:      Georgia;
//     position:         relative;
//     float:            left;
//     border:           2px solid red;
//     width:            600px;
//     padding-left:     20px;
//     padding-right:    20px;
//     padding-top:      10px;
//     font-family:      'Sacramento', cursive;
//     font-size:        26px;
//     background-color: #F4EBF3;
//     border-radius:    15px;
// }
//
// </Style>
//
// </style>

// %% [markdown]
// # PicoSat

// %% [markdown]
// In TypeScript/JavaScript, there is no direct equivalent to pycosat, but a great alternative is the theorem prover [Z3](https://github.com/Z3Prover/z3) with the npm package `z3-solver`.

// %%
import { Z3 } from "z3-solver";
// Out:
// 1:10 - Module '"z3-solver"' has no exported member 'Z3'.

// %% [markdown]
// In the Z3 solver, propositional variables are represented using boolean constants:
//
// - A propositional variable \(p\) is created as a boolean variable: `p = Bool("p")`.
// - Negation \(\neg p\) is represented with `Not(p)`.
// - A clause is represented as a disjunction of literals, for example: `Or(p, Not(q), r)`.
// - A CNF formula is a conjunction of such clauses

// %%
import { init } from "z3-solver";

async function runExample() {
  const Z3 = await init();
  const ctx = Z3.Context("");

  // Declare boolean variables corresponding to 1, 2, 3
  const p = ctx.Bool.const("p");
  const q = ctx.Bool.const("q");
  const r = ctx.Bool.const("r");

  // Translate each clause from f = [ [1, -2, 3], [-1, 2, -3], [-1, -2, 3], [1, 2, -3] ]
  const clause1 = ctx.Or(p, ctx.Not(q), r);
  const clause2 = ctx.Or(ctx.Not(p), q, ctx.Not(r));
  const clause3 = ctx.Or(ctx.Not(p), ctx.Not(q), r);
  const clause4 = ctx.Or(p, q, ctx.Not(r));

  // Form the CNF conjunction of clauses
  const formula = ctx.And(clause1, clause2, clause3, clause4);

  // Create a solver instance and add the formula
  const solver = new ctx.Solver();
  solver.add(formula);

  // Check satisfiability of the formula
  const result = await solver.check();

  console.log(result.toString());
    if (result.toString() === "sat") {
    const model = solver.model();
    console.log("Model:");
    console.log(model.toString());
  }
}

await runExample();
// Out:
// sat
// Model:
// (define-fun p () Bool
//   false)
// (define-fun q () Bool
//   false)
// (define-fun r () Bool
//   false)

// %% [markdown]
// In order to check whether this formula is satifiable, we can use the method `pycosat.solve` as follows:

// %%
pycosat.solve(f)
// Out:
// 1:1 - Cannot find name 'pycosat'.
// 1:15 - Cannot find name 'f'.

// %% [markdown]
// This shows that the formula `f` is satisfiable and that the  propositional valuation
// $$ \mathcal{I} = \{ p \mapsto \texttt{False}, q \mapsto \texttt{False}, r \mapsto \texttt{False} \} $$
// is a solution for `f`, i.e. we have
// $$ \mathcal{I}(\texttt{f}) = \texttt{True}. $$

// %% [markdown]
// ## Transforming Clauses into PyCoSat Format

// %% [markdown]
// In order to use *PicoSat* for the examples discussed in our lecture, we need a function that transforms a formula that is in conjunctive normal form
// into the format of *PicoSat*.  Furthermore, we need a function that can translate a solution found by *PicoSat* back into our format.

// %% [markdown]
// The function `findVariables` takes a set of `Clauses` and returns the set of all propositional variables
// occurring in this set.

// %%
function findVariables(Clauses: Clause[]): Set<Variable> {
  const Variables = new Set<Variable>();
  for (const Clause of Clauses) {
    for (const literal of Clause) {
      if (Array.isArray(literal) && literal[0] === '¬') {
        Variables.add(literal[1]);
      } else if (typeof literal === 'string') {
        Variables.add(literal);
      }
    }
  }
  return Variables;
}
// Out:
// 6:23 - Argument of type 'number' is not assignable to parameter of type 'string'.

// %% [markdown]
// The function `numberVariables(Clauses)` takes a set of `Clauses` as input.  It returns two dictionaries:
// * The dictionary `Var2Int` maps every propositional variable occurring in `Clauses` to a unique natural number.
// * The dictionary `Int2Var` is the mapping that is inverse to the dictionary `Var2Int`.

// %%
function numberVariables(Clauses: Clause[]): [Map<Variable, number>, Map<number, Variable>] {
  const Variables = findVariables(Clauses);
  let count = 1;
  const Var2Int = new Map<Variable, number>();
  const Int2Var = new Map<number, Variable>();
  for (const variable of Variables) {
    Var2Int.set(variable, count);
    Int2Var.set(count, variable);
    count += 1;
  }
  return [Var2Int, Int2Var];
}

// %% [markdown]
// The function `literal2int` takes a literal and transforms this literal into an integer
// representing the literal.  If the literal is a negated variable, the integer is negative, else it is positive.
// `Var2Int` is a dictionary mapping propositional variables to natural numbers.

// %%
function literal2int(literal: Literal, Var2Int: Map<Variable, number>): number {
  if (Array.isArray(literal) && literal[0] === '¬') {
    // Extract string variable name for lookup
    return -Var2Int.get(literal[1])!;
  } else if (typeof literal === 'string') {
    return Var2Int.get(literal)!;
  } else {
    throw new Error("Invalid literal format");
  }
}
// Out:
// 4:25 - Argument of type 'number' is not assignable to parameter of type 'string'.

// %% [markdown]
// The function `clause2pyco(Clause, Var2Int)` transforms a set of literals into a list of integers.
// `Var2Int` is a dictionary mapping the propositional variables to integers.

// %%
function literal2int(literal: Literal, Var2Int: Map<string, number>): number {
  if (Array.isArray(literal) && literal[0] === '¬') {
    return -Var2Int.get(literal[1])!;
  } else if (typeof literal === 'number') {
    return literal;
  } else {
    // Assuming literal is variable name string before mapping
    return Var2Int.get(literal)!;
  }
}
// Out:
// 3:25 - Argument of type 'number' is not assignable to parameter of type 'string'.
// 8:24 - Argument of type '[string, number]' is not assignable to parameter of type 'string'.

// %% [markdown]
// The function `clauses2pyco(Clauses, Var2Int)` transforms a set of `Clauses` into a list of lists of integers.
// `Var2Int` is a dictionary mapping the propositional variables to integers.

// %%
function clauses2pyco(Clauses: Clause[], Var2Int: Map<Variable, number>): number[][] {
  return Clauses.map(clause => clause2pyco(clause, Var2Int));
}
// Out:
// 2:52 - Argument of type 'Map<string, number>' is not assignable to parameter of type 'Map<number, number>'.
// 2:52 - Type 'string' is not assignable to type 'number'.

// %% [markdown]
// The function `int2var(Numbers, Int2Var)` takes a list of numbers representing a set of literals
// and returns the associated list of literals.

// %%
function int2var(Numbers: number[], Int2Var: Map<number, Variable>): Set<Set<Literal>> {
  const Result = new Set<Set<Literal>>();
  for (const n of Numbers) {
    if (n > 0) {
      Result.add(new Set<Literal>([Int2Var.get(n)!]));
    } else {
      Result.add(new Set<Literal>([['¬', Int2Var.get(-n)!]]));
    }
  }
  return Result;
}
// Out:
// 5:18 - No overload matches this call.
// 5:18 - Overload 1 of 2, '(iterable?: Iterable<Literal>): Set<Literal>', gave the following error.
// 5:18 - Argument of type 'string[]' is not assignable to parameter of type 'Iterable<Literal>'.
// 5:18 - The types returned by '[Symbol.iterator]().next(...)' are incompatible between these types.
// 5:18 - Type 'IteratorResult<string, any>' is not assignable to type 'IteratorResult<Literal, any>'.
// 5:18 - Type 'IteratorYieldResult<string>' is not assignable to type 'IteratorResult<Literal, any>'.
// 5:18 - Type 'IteratorYieldResult<string>' is not assignable to type 'IteratorYieldResult<Literal>'.
// 5:18 - Type 'string' is not assignable to type 'Literal'.
// 5:18 - Overload 2 of 2, '(values?: readonly Literal[]): Set<Literal>', gave the following error.
// 5:18 - Type 'string' is not assignable to type 'Literal'.
// 7:18 - No overload matches this call.
// 7:18 - Overload 1 of 2, '(iterable?: Iterable<Literal>): Set<Literal>', gave the following error.
// 7:18 - Argument of type '[string, string][]' is not assignable to parameter of type 'Iterable<Literal>'.
// 7:18 - The types returned by '[Symbol.iterator]().next(...)' are incompatible between these types.
// 7:18 - Type 'IteratorResult<[string, string], any>' is not assignable to type 'IteratorResult<Literal, any>'.
// 7:18 - Type 'IteratorYieldResult<[string, string]>' is not assignable to type 'IteratorResult<Literal, any>'.
// 7:18 - Type 'IteratorYieldResult<[string, string]>' is not assignable to type 'IteratorYieldResult<Literal>'.
// 7:18 - Type '[string, string]' is not assignable to type 'Literal'.
// 7:18 - Type '[string, string]' is not assignable to type '[string, number]'.
// 7:18 - Type at position 1 in source is not compatible with type at position 1 in target.
// 7:18 - Type 'string' is not assignable to type 'number'.
// 7:18 - Overload 2 of 2, '(values?: readonly Literal[]): Set<Literal>', gave the following error.
// 7:18 - Type 'string' is not assignable to type 'number'.

// %% [markdown]
// ## Sudoku

// %%
type Variable = string;
type Literal = Variable | ['¬', Variable];
type Clause = Set<Literal>;

// %% [markdown]
// The finish mathematician Arto Inkala claims to have created the [hardest sudoku](https://abcnews.go.com/blogs/headlines/2012/06/can-you-solve-the-hardest-ever-sudoku) ever.  It is defined below.

// %%
function createPuzzle(): (number | string)[][] {
  return [
    [ 8 , "*", "*", "*", "*", "*", "*", "*", "*"], 
    ["*", "*",  3 ,  6 , "*", "*", "*", "*", "*"],
    ["*",  7 , "*", "*",  9 , "*",  2 , "*", "*"],
    ["*",  5 , "*", "*", "*",  7 , "*", "*", "*"],
    ["*", "*", "*", "*",  4 ,  5 ,  7 , "*", "*"],
    ["*", "*", "*",  1 , "*", "*", "*",  3 , "*"],
    ["*", "*",  1 , "*", "*", "*", "*",  6 ,  8 ],
    ["*", "*",  8 ,  5 , "*", "*", "*",  1 , "*"],
    ["*",  9 , "*", "*", "*", "*",  4 , "*", "*"]
  ];
}

// %% [markdown]
// We will solve this Sudoku using the Davis-Putnam algorithm.  We use the following variables:
// * `Q<r,c,d>` is a Boolean variable stating that the field in row `r` and column `c` holds the digit `d`.
//   Here, `r`, `c`, `d` are all elements from the set $\{1,\cdots,9\}$.
//
// The function `var(row, col, digit)` returns a formated string that is interpreted as a variable name.

// %%
function varName(row: number, col: number, digit: number): string {
    return `Q<${row},${col},${digit}>`;
}

// %%
varName(1,2,3);
// Out:
// Q<1,2,3>

// %% [markdown]
// The function `atMostOne(S)` takes a set `S` of propositional variables as its argument.  It returns a set of clauses
// expressing the fact that at most one of the variables of `S` is true.

// %%
function atMostOne(S: Set<Variable>): Set<Clause> {
    const result = new Set<Clause>();
    const arr = Array.from(S);
    for (let i = 0; i < arr.length; i++) {
        for (let j = i + 1; j < arr.length; j++) {
            const p = arr[i];
            const q = arr[j];
            result.add(new Set<Literal>([['¬', p], ['¬', q]]));
        }
    }
    return result;
}

// %% [markdown]
// The function `atLeastOne(S)` takes a set `S` of propositional variables as its argument.  It returns a set of clauses
// expressing the fact that at least one of the variables of `S` is true.

// %%
function atLeastOne(S: Set<Variable>): Set<Clause> {
    return new Set([new Set(S)]);
}

// %% [markdown]
// The function `exactlyOne(S)` takes a set `S` of propositional variables as its argument.  It returns a set of clauses
// expressing the fact that exactly one of the variables of `S` is true.

// %%
function exactlyOne(S: Set<Variable>): Set<Clause> {
    const atMost = atMostOne(S);
    const atLeast = atLeastOne(S);
    return new Set([...atMost, ...atLeast]);
}

// %%
exactlyOne(new Set(['a', 'b', 'c']));
// Out:
// Set(4) {
//   Set(2) { [ '¬', 'a' ], [ '¬', 'b' ] },
//   Set(2) { [ '¬', 'a' ], [ '¬', 'c' ] },
//   Set(2) { [ '¬', 'b' ], [ '¬', 'c' ] },
//   Set(3) { 'a', 'b', 'c' }
// }

// %% [markdown]
// The function `exactlyOnce` takes a list `L` of pairs of indices as its argument.  The elements of `L` are pairs of the form
// `(row, col)`, where both `row` and `col` are elements of the set $\{1, \cdots, 9\}$.
// It returns a set of formulas expressing that all Sudoku fields specified by the coordinate pairs in `L` take different digits as values.

// %%
function exactlyOnce(L: Array<[number, number]>): Set<Clause> {
    const Clauses = new Set<Clause>();
    for (let digit = 1; digit <= 9; digit++) {
        const vars = new Set<Variable>(
            L.map(([row, col]) => varName(row, col, digit))
        );
        const exact = exactlyOne(vars);
        for (const clause of exact) {
            Clauses.add(clause);
        }
    }
    return Clauses;
}

// %%
const result = exactlyOnce(
    Array.from({ length: 9 }, (_, i) => [1, i + 1] as [number, number])
);
console.log(result.size)
for (const clause of result) {
    console.log(`{${[...clause].map(lit => JSON.stringify(lit)).join(', ')}}`);
}
// Out:
// 333
// {["¬","Q<1,1,1>"], ["¬","Q<1,2,1>"]}
// {["¬","Q<1,1,1>"], ["¬","Q<1,3,1>"]}
// {["¬","Q<1,1,1>"], ["¬","Q<1,4,1>"]}
// {["¬","Q<1,1,1>"], ["¬","Q<1,5,1>"]}
// {["¬","Q<1,1,1>"], ["¬","Q<1,6,1>"]}
// {["¬","Q<1,1,1>"], ["¬","Q<1,7,1>"]}
// {["¬","Q<1,1,1>"], ["¬","Q<1,8,1>"]}
// {["¬","Q<1,1,1>"], ["¬","Q<1,9,1>"]}
// {["¬","Q<1,2,1>"], ["¬","Q<1,3,1>"]}
// {["¬","Q<1,2,1>"], ["¬","Q<1,4,1>"]}
// {["¬","Q<1,2,1>"], ["¬","Q<1,5,1>"]}
// {["¬","Q<1,2,1>"], ["¬","Q<1,6,1>"]}
// {["¬","Q<1,2,1>"], ["¬","Q<1,7,1>"]}
// {["¬","Q<1,2,1>"], ["¬","Q<1,8,1>"]}
// {["¬","Q<1,2,1>"], ["¬","Q<1,9,1>"]}
// {["¬","Q<1,3,1>"], ["¬","Q<1,4,1>"]}
// {["¬","Q<1,3,1>"], ["¬","Q<1,5,1>"]}
// {["¬","Q<1,3,1>"], ["¬","Q<1,6,1>"]}
// {["¬","Q<1,3,1>"], ["¬","Q<1,7,1>"]}
// {["¬","Q<1,3,1>"], ["¬","Q<1,8,1>"]}
// {["¬","Q<1,3,1>"], ["¬","Q<1,9,1>"]}
// {["¬","Q<1,4,1>"], ["¬","Q<1,5,1>"]}
// {["¬","Q<1,4,1>"], ["¬","Q<1,6,1>"]}
// {["¬","Q<1,4,1>"], ["¬","Q<1,7,1>"]}
// {["¬","Q<1,4,1>"], ["¬","Q<1,8,1>"]}
// {["¬","Q<1,4,1>"], ["¬","Q<1,9,1>"]}
// {["¬","Q<1,5,1>"], ["¬","Q<1,6,1>"]}
// {["¬","Q<1,5,1>"], ["¬","Q<1,7,1>"]}
// {["¬","Q<1,5,1>"], ["¬","Q<1,8,1>"]}
// {["¬","Q<1,5,1>"], ["¬","Q<1,9,1>"]}
// {["¬","Q<1,6,1>"], ["¬","Q<1,7,1>"]}
// {["¬","Q<1,6,1>"], ["¬","Q<1,8,1>"]}
// {"Q<1,1,2>", "Q<1,2,2>", "Q<1,3,2>", "Q<1,4,2>", "Q<1,5,2>", "Q<1,6,2>", "Q<1,7,2>", "Q<1,8,2>", "Q<1,9,2>"}
// {["¬","Q<1,1,3>"], ["¬","Q<1,2,3>"]}
// {["¬","Q<1,1,3>"], ["¬","Q<1,3,3>"]}
// {["¬","Q<1,1,3>"], ["¬","Q<1,4,3>"]}
// {["¬","Q<1,1,3>"], ["¬","Q<1,5,3>"]}
// {["¬","Q<1,1,3>"], ["¬","Q<1,6,3>"]}
// {["¬","Q<1,1,3>"], ["¬","Q<1,7,3>"]}
// {["¬","Q<1,1,3>"], ["¬","Q<1,8,3>"]}
// {["¬","Q<1,1,3>"], ["¬","Q<1,9,3>"]}
// {["¬","Q<1,2,3>"], ["¬","Q<1,3,3>"]}
// {["¬","Q<1,2,3>"], ["¬","Q<1,4,3>"]}
// {["¬","Q<1,2,3>"], ["¬","Q<1,5,3>"]}
// {["¬","Q<1,2,3>"], ["¬","Q<1,6,3>"]}
// {["¬","Q<1,2,3>"], ["¬","Q<1,7,3>"]}
// {["¬","Q<1,2,3>"], ["¬","Q<1,8,3>"]}
// {["¬","Q<1,2,3>"], ["¬","Q<1,9,3>"]}
// {["¬","Q<1,3,3>"], ["¬","Q<1,4,3>"]}
// {["¬","Q<1,3,3>"], ["¬","Q<1,5,3>"]}
// {["¬","Q<1,3,3>"], ["¬","Q<1,6,3>"]}
// {["¬","Q<1,3,3>"], ["¬","Q<1,7,3>"]}
// {["¬","Q<1,3,3>"], ["¬","Q<1,8,3>"]}
// {["¬","Q<1,3,3>"], ["¬","Q<1,9,3>"]}
// {["¬","Q<1,4,3>"], ["¬","Q<1,5,3>"]}
// {["¬","Q<1,4,3>"], ["¬","Q<1,6,3>"]}
// {["¬","Q<1,4,3>"], ["¬","Q<1,7,3>"]}
// {["¬","Q<1,4,3>"], ["¬","Q<1,8,3>"]}
// {["¬","Q<1,4,3>"], ["¬","Q<1,9,3>"]}
// {["¬","Q<1,5,3>"], ["¬","Q<1,6,3>"]}
// {["¬","Q<1,5,3>"], ["¬","Q<1,7,3>"]}
// {["¬","Q<1,5,3>"], ["¬","Q<1,8,3>"]}
// {["¬","Q<1,5,3>"], ["¬","Q<1,9,3>"]}
// {["¬","Q<1,6,3>"], ["¬","Q<1,7,3>"]}
// {["¬","Q<1,6,3>"], ["¬","Q<1,8,3>"]}
// {["¬","Q<1,6,3>"], ["¬","Q<1,9,3>"]}
// {["¬","Q<1,7,3>"], ["¬","Q<1,8,3>"]}
// {["¬","Q<1,7,3>"], ["¬","Q<1,9,3>"]}
// {["¬","Q<1,8,3>"], ["¬","Q<1,9,3>"]}
// {"Q<1,1,3>", "Q<1,2,3>", "Q<1,3,3>", "Q<1,4,3>", "Q<1,5,3>", "Q<1,6,3>", "Q<1,7,3>", "Q<1,8,3>", "Q<1,9,3>"}
// {["¬","Q<1,1,4>"], ["¬","Q<1,2,4>"]}
// {["¬","Q<1,1,4>"], ["¬","Q<1,3,4>"]}
// {["¬","Q<1,1,4>"], ["¬","Q<1,4,4>"]}
// {["¬","Q<1,1,4>"], ["¬","Q<1,5,4>"]}
// {["¬","Q<1,1,4>"], ["¬","Q<1,6,4>"]}
// {["¬","Q<1,1,4>"], ["¬","Q<1,7,4>"]}
// {["¬","Q<1,1,4>"], ["¬","Q<1,8,4>"]}
// {["¬","Q<1,1,4>"], ["¬","Q<1,9,4>"]}
// {["¬","Q<1,2,4>"], ["¬","Q<1,3,4>"]}
// {["¬","Q<1,2,4>"], ["¬","Q<1,4,4>"]}
// {["¬","Q<1,2,4>"], ["¬","Q<1,5,4>"]}
// {["¬","Q<1,2,4>"], ["¬","Q<1,6,4>"]}
// {["¬","Q<1,2,4>"], ["¬","Q<1,7,4>"]}
// {["¬","Q<1,2,4>"], ["¬","Q<1,8,4>"]}
// {["¬","Q<1,2,4>"], ["¬","Q<1,9,4>"]}
// {["¬","Q<1,3,4>"], ["¬","Q<1,4,4>"]}
// {["¬","Q<1,3,4>"], ["¬","Q<1,5,4>"]}
// {["¬","Q<1,3,4>"], ["¬","Q<1,6,4>"]}
// {["¬","Q<1,3,4>"], ["¬","Q<1,7,4>"]}
// {["¬","Q<1,3,4>"], ["¬","Q<1,8,4>"]}
// {["¬","Q<1,3,4>"], ["¬","Q<1,9,4>"]}
// {["¬","Q<1,4,4>"], ["¬","Q<1,5,4>"]}
// {["¬","Q<1,4,4>"], ["¬","Q<1,6,4>"]}
// {["¬","Q<1,4,4>"], ["¬","Q<1,7,4>"]}
// {["¬","Q<1,4,4>"], ["¬","Q<1,8,4>"]}
// {["¬","Q<1,4,4>"], ["¬","Q<1,9,4>"]}
// {["¬","Q<1,5,4>"], ["¬","Q<1,6,4>"]}
// {["¬","Q<1,5,4>"], ["¬","Q<1,7,4>"]}
// {["¬","Q<1,5,4>"], ["¬","Q<1,8,4>"]}
// {["¬","Q<1,5,4>"], ["¬","Q<1,9,4>"]}
// {["¬","Q<1,6,4>"], ["¬","Q<1,7,4>"]}
// {["¬","Q<1,6,4>"], ["¬","Q<1,8,4>"]}
// {["¬","Q<1,6,4>"], ["¬","Q<1,9,4>"]}
// {["¬","Q<1,7,4>"], ["¬","Q<1,8,4>"]}
// {["¬","Q<1,7,4>"], ["¬","Q<1,9,4>"]}
// {["¬","Q<1,8,4>"], ["¬","Q<1,9,4>"]}
// {"Q<1,1,4>", "Q<1,2,4>", "Q<1,3,4>", "Q<1,4,4>", "Q<1,5,4>", "Q<1,6,4>", "Q<1,7,4>", "Q<1,8,4>", "Q<1,9,4>"}
// {["¬","Q<1,1,5>"], ["¬","Q<1,2,5>"]}
// {["¬","Q<1,1,5>"], ["¬","Q<1,3,5>"]}
// {["¬","Q<1,1,5>"], ["¬","Q<1,4,5>"]}
// {["¬","Q<1,1,5>"], ["¬","Q<1,5,5>"]}
// {["¬","Q<1,1,5>"], ["¬","Q<1,6,5>"]}
// {["¬","Q<1,1,5>"], ["¬","Q<1,7,5>"]}
// {["¬","Q<1,1,5>"], ["¬","Q<1,8,5>"]}
// {["¬","Q<1,1,5>"], ["¬","Q<1,9,5>"]}
// {["¬","Q<1,2,5>"], ["¬","Q<1,3,5>"]}
// {["¬","Q<1,2,5>"], ["¬","Q<1,4,5>"]}
// {["¬","Q<1,2,5>"], ["¬","Q<1,5,5>"]}
// {["¬","Q<1,2,5>"], ["¬","Q<1,6,5>"]}
// {["¬","Q<1,2,5>"], ["¬","Q<1,7,5>"]}
// {["¬","Q<1,2,5>"], ["¬","Q<1,8,5>"]}
// {["¬","Q<1,2,5>"], ["¬","Q<1,9,5>"]}
// {["¬","Q<1,3,5>"], ["¬","Q<1,4,5>"]}
// {["¬","Q<1,3,5>"], ["¬","Q<1,5,5>"]}
// {["¬","Q<1,3,5>"], ["¬","Q<1,6,5>"]}
// {["¬","Q<1,3,5>"], ["¬","Q<1,7,5>"]}
// {["¬","Q<1,3,5>"], ["¬","Q<1,8,5>"]}
// {["¬","Q<1,3,5>"], ["¬","Q<1,9,5>"]}
// {["¬","Q<1,4,5>"], ["¬","Q<1,5,5>"]}
// {["¬","Q<1,4,5>"], ["¬","Q<1,6,5>"]}
// {["¬","Q<1,4,5>"], ["¬","Q<1,7,5>"]}
// {["¬","Q<1,4,5>"], ["¬","Q<1,8,5>"]}
// {["¬","Q<1,4,5>"], ["¬","Q<1,9,5>"]}
// {["¬","Q<1,5,5>"], ["¬","Q<1,6,5>"]}
// {["¬","Q<1,5,5>"], ["¬","Q<1,7,5>"]}
// {["¬","Q<1,5,5>"], ["¬","Q<1,8,5>"]}
// {["¬","Q<1,5,5>"], ["¬","Q<1,9,5>"]}
// {["¬","Q<1,6,5>"], ["¬","Q<1,7,5>"]}
// {["¬","Q<1,6,5>"], ["¬","Q<1,8,5>"]}
// {["¬","Q<1,6,5>"], ["¬","Q<1,9,5>"]}
// {["¬","Q<1,7,5>"], ["¬","Q<1,8,5>"]}
// {["¬","Q<1,7,5>"], ["¬","Q<1,9,5>"]}
// {["¬","Q<1,8,5>"], ["¬","Q<1,9,5>"]}
// {"Q<1,1,5>", "Q<1,2,5>", "Q<1,3,5>", "Q<1,4,5>", "Q<1,5,5>", "Q<1,6,5>", "Q<1,7,5>", "Q<1,8,5>", "Q<1,9,5>"}
// {["¬","Q<1,1,6>"], ["¬","Q<1,2,6>"]}
// {["¬","Q<1,1,6>"], ["¬","Q<1,3,6>"]}
// {["¬","Q<1,1,6>"], ["¬","Q<1,4,6>"]}
// {["¬","Q<1,1,6>"], ["¬","Q<1,5,6>"]}
// {["¬","Q<1,1,6>"], ["¬","Q<1,6,6>"]}
// {["¬","Q<1,1,6>"], ["¬","Q<1,7,6>"]}
// {["¬","Q<1,1,6>"], ["¬","Q<1,8,6>"]}
// {["¬","Q<1,1,6>"], ["¬","Q<1,9,6>"]}
// {["¬","Q<1,2,6>"], ["¬","Q<1,3,6>"]}
// {["¬","Q<1,2,6>"], ["¬","Q<1,4,6>"]}
// {["¬","Q<1,2,6>"], ["¬","Q<1,5,6>"]}
// {["¬","Q<1,2,6>"], ["¬","Q<1,6,6>"]}
// {["¬","Q<1,2,6>"], ["¬","Q<1,7,6>"]}
// {["¬","Q<1,2,6>"], ["¬","Q<1,8,6>"]}
// {["¬","Q<1,2,6>"], ["¬","Q<1,9,6>"]}
// {["¬","Q<1,3,6>"], ["¬","Q<1,4,6>"]}
// {["¬","Q<1,3,6>"], ["¬","Q<1,5,6>"]}
// {["¬","Q<1,3,6>"], ["¬","Q<1,6,6>"]}
// {["¬","Q<1,3,6>"], ["¬","Q<1,7,6>"]}
// {["¬","Q<1,3,6>"], ["¬","Q<1,8,6>"]}
// {["¬","Q<1,3,6>"], ["¬","Q<1,9,6>"]}
// {["¬","Q<1,4,6>"], ["¬","Q<1,5,6>"]}
// {["¬","Q<1,4,6>"], ["¬","Q<1,6,6>"]}
// {["¬","Q<1,4,6>"], ["¬","Q<1,7,6>"]}
// {["¬","Q<1,4,6>"], ["¬","Q<1,8,6>"]}
// {["¬","Q<1,4,6>"], ["¬","Q<1,9,6>"]}
// {["¬","Q<1,5,6>"], ["¬","Q<1,6,6>"]}
// {["¬","Q<1,5,6>"], ["¬","Q<1,7,6>"]}
// {["¬","Q<1,5,6>"], ["¬","Q<1,8,6>"]}
// {["¬","Q<1,5,6>"], ["¬","Q<1,9,6>"]}
// {["¬","Q<1,6,6>"], ["¬","Q<1,7,6>"]}
// {["¬","Q<1,6,6>"], ["¬","Q<1,8,6>"]}
// {["¬","Q<1,6,6>"], ["¬","Q<1,9,6>"]}
// {["¬","Q<1,7,6>"], ["¬","Q<1,8,6>"]}
// {["¬","Q<1,7,6>"], ["¬","Q<1,9,6>"]}
// {["¬","Q<1,8,6>"], ["¬","Q<1,9,6>"]}
// {"Q<1,1,6>", "Q<1,2,6>", "Q<1,3,6>", "Q<1,4,6>", "Q<1,5,6>", "Q<1,6,6>", "Q<1,7,6>", "Q<1,8,6>", "Q<1,9,6>"}
// {["¬","Q<1,1,7>"], ["¬","Q<1,2,7>"]}
// {["¬","Q<1,1,7>"], ["¬","Q<1,3,7>"]}
// {["¬","Q<1,1,7>"], ["¬","Q<1,4,7>"]}
// {["¬","Q<1,1,7>"], ["¬","Q<1,5,7>"]}
// {["¬","Q<1,1,7>"], ["¬","Q<1,6,7>"]}
// {["¬","Q<1,1,7>"], ["¬","Q<1,7,7>"]}
// {["¬","Q<1,1,7>"], ["¬","Q<1,8,7>"]}
// {["¬","Q<1,1,7>"], ["¬","Q<1,9,7>"]}
// {["¬","Q<1,2,7>"], ["¬","Q<1,3,7>"]}
// {["¬","Q<1,2,7>"], ["¬","Q<1,4,7>"]}
// {["¬","Q<1,2,7>"], ["¬","Q<1,5,7>"]}
// {["¬","Q<1,2,7>"], ["¬","Q<1,6,7>"]}
// {["¬","Q<1,2,7>"], ["¬","Q<1,7,7>"]}
// {["¬","Q<1,2,7>"], ["¬","Q<1,8,7>"]}
// {["¬","Q<1,2,7>"], ["¬","Q<1,9,7>"]}
// {["¬","Q<1,3,7>"], ["¬","Q<1,4,7>"]}
// {["¬","Q<1,3,7>"], ["¬","Q<1,5,7>"]}
// {["¬","Q<1,3,7>"], ["¬","Q<1,6,7>"]}
// {["¬","Q<1,5,9>"], ["¬","Q<1,8,9>"]}
// {["¬","Q<1,5,9>"], ["¬","Q<1,9,9>"]}
// {["¬","Q<1,6,9>"], ["¬","Q<1,7,9>"]}
// {["¬","Q<1,6,9>"], ["¬","Q<1,8,9>"]}
// {["¬","Q<1,6,9>"], ["¬","Q<1,9,9>"]}
// {["¬","Q<1,7,9>"], ["¬","Q<1,8,9>"]}
// {["¬","Q<1,7,9>"], ["¬","Q<1,9,9>"]}
// {["¬","Q<1,8,9>"], ["¬","Q<1,9,9>"]}
// {"Q<1,1,9>", "Q<1,2,9>", "Q<1,3,9>", "Q<1,4,9>", "Q<1,5,9>", "Q<1,6,9>", "Q<1,7,9>", "Q<1,8,9>", "Q<1,9,9>"}

// %% [markdown]
// The function `exactlyOneDigit(row, col)` takes integers `row` and `col` as arguments.  These specify the row and column of a field in a Sudoku.  The function returns a set of clauses specifying that exactly one of the variables
//
// * `Q<row,col,1>`, `Q<row,col,2>`, $\cdots$, `Q<row,col,9>`
//
// is `True`.

// %%
function exactlyOneDigit(row: number, col: number): Set<Clause> {
    const vars = new Set<Variable>();
    for (let digit = 1; digit <= 9; digit++) {
        vars.add(varName(row, col, digit));
    }
    return exactlyOne(vars);
}

// %%
exactlyOneDigit(1, 1);
// Out:
// Set(37) {
//   Set(2) { [ '¬', 'Q<1,1,1>' ], [ '¬', 'Q<1,1,2>' ] },
//   Set(2) { [ '¬', 'Q<1,1,1>' ], [ '¬', 'Q<1,1,3>' ] },
//   Set(2) { [ '¬', 'Q<1,1,1>' ], [ '¬', 'Q<1,1,4>' ] },
//   Set(2) { [ '¬', 'Q<1,1,1>' ], [ '¬', 'Q<1,1,5>' ] },
//   Set(2) { [ '¬', 'Q<1,1,1>' ], [ '¬', 'Q<1,1,6>' ] },
//   Set(2) { [ '¬', 'Q<1,1,1>' ], [ '¬', 'Q<1,1,7>' ] },
//   Set(2) { [ '¬', 'Q<1,1,1>' ], [ '¬', 'Q<1,1,8>' ] },
//   Set(2) { [ '¬', 'Q<1,1,1>' ], [ '¬', 'Q<1,1,9>' ] },
//   Set(2) { [ '¬', 'Q<1,1,2>' ], [ '¬', 'Q<1,1,3>' ] },
//   Set(2) { [ '¬', 'Q<1,1,2>' ], [ '¬', 'Q<1,1,4>' ] },
//   Set(2) { [ '¬', 'Q<1,1,2>' ], [ '¬', 'Q<1,1,5>' ] },
//   Set(2) { [ '¬', 'Q<1,1,2>' ], [ '¬', 'Q<1,1,6>' ] },
//   Set(2) { [ '¬', 'Q<1,1,2>' ], [ '¬', 'Q<1,1,7>' ] },
//   Set(2) { [ '¬', 'Q<1,1,2>' ], [ '¬', 'Q<1,1,8>' ] },
//   Set(2) { [ '¬', 'Q<1,1,2>' ], [ '¬', 'Q<1,1,9>' ] },
//   Set(2) { [ '¬', 'Q<1,1,3>' ], [ '¬', 'Q<1,1,4>' ] },
//   Set(2) { [ '¬', 'Q<1,1,3>' ], [ '¬', 'Q<1,1,5>' ] },
//   Set(2) { [ '¬', 'Q<1,1,3>' ], [ '¬', 'Q<1,1,6>' ] },
//   Set(2) { [ '¬', 'Q<1,1,3>' ], [ '¬', 'Q<1,1,7>' ] },
//   Set(2) { [ '¬', 'Q<1,1,3>' ], [ '¬', 'Q<1,1,8>' ] },
//   Set(2) { [ '¬', 'Q<1,1,3>' ], [ '¬', 'Q<1,1,9>' ] },
//   Set(2) { [ '¬', 'Q<1,1,4>' ], [ '¬', 'Q<1,1,5>' ] },
//   Set(2) { [ '¬', 'Q<1,1,4>' ], [ '¬', 'Q<1,1,6>' ] },
//   Set(2) { [ '¬', 'Q<1,1,4>' ], [ '¬', 'Q<1,1,7>' ] },
//   Set(2) { [ '¬', 'Q<1,1,4>' ], [ '¬', 'Q<1,1,8>' ] },
//   Set(2) { [ '¬', 'Q<1,1,4>' ], [ '¬', 'Q<1,1,9>' ] },
//   Set(2) { [ '¬', 'Q<1,1,5>' ], [ '¬', 'Q<1,1,6>' ] },
//   Set(2) { [ '¬', 'Q<1,1,5>' ], [ '¬', 'Q<1,1,7>' ] },
//   Set(2) { [ '¬', 'Q<1,1,5>' ], [ '¬', 'Q<1,1,8>' ] },
//   Set(2) { [ '¬', 'Q<1,1,5>' ], [ '¬', 'Q<1,1,9>' ] },
//   Set(2) { [ '¬', 'Q<1,1,6>' ], [ '¬', 'Q<1,1,7>' ] },
//   Set(2) { [ '¬', 'Q<1,1,6>' ], [ '¬', 'Q<1,1,8>' ] },
//   Set(2) { [ '¬', 'Q<1,1,6>' ], [ '¬', 'Q<1,1,9>' ] },
//   Set(2) { [ '¬', 'Q<1,1,7>' ], [ '¬', 'Q<1,1,8>' ] },
//   Set(2) { [ '¬', 'Q<1,1,7>' ], [ '¬', 'Q<1,1,9>' ] },
//   Set(2) { [ '¬', 'Q<1,1,8>' ], [ '¬', 'Q<1,1,9>' ] },
//   Set(9) {
//     'Q<1,1,1>',
//     'Q<1,1,2>',
//     'Q<1,1,3>',
//     'Q<1,1,4>',
//     'Q<1,1,5>',
//     'Q<1,1,6>',
//     'Q<1,1,7>',
//     'Q<1,1,8>',
//     'Q<1,1,9>'
//   }
// }

// %% [markdown]
// The function `constraints_from_puzzle`  returns a set of clauses stating that the variables corresponding to numbers that are already given in the Sudoku puzzle take the values that are specified.

// %%
function constraintsFromPuzzle(): Set<Clause> {
    const Puzzle = createPuzzle();
    const Variables: Variable[] = [];
    for (let row = 0; row < 9; row++) {
        for (let col = 0; col < 9; col++) {
            if (Puzzle[row][col] !== '*') {
                Variables.push(varName(row + 1, col + 1, Puzzle[row][col] as number));
            }
        }
    }
    return new Set(Variables.map(v => new Set<Literal>([v])));
}

// %%
constraintsFromPuzzle();
// Out:
// Set(21) {
//   Set(1) { 'Q<1,1,8>' },
//   Set(1) { 'Q<2,3,3>' },
//   Set(1) { 'Q<2,4,6>' },
//   Set(1) { 'Q<3,2,7>' },
//   Set(1) { 'Q<3,5,9>' },
//   Set(1) { 'Q<3,7,2>' },
//   Set(1) { 'Q<4,2,5>' },
//   Set(1) { 'Q<4,6,7>' },
//   Set(1) { 'Q<5,5,4>' },
//   Set(1) { 'Q<5,6,5>' },
//   Set(1) { 'Q<5,7,7>' },
//   Set(1) { 'Q<6,4,1>' },
//   Set(1) { 'Q<6,8,3>' },
//   Set(1) { 'Q<7,3,1>' },
//   Set(1) { 'Q<7,8,6>' },
//   Set(1) { 'Q<7,9,8>' },
//   Set(1) { 'Q<8,3,8>' },
//   Set(1) { 'Q<8,4,5>' },
//   Set(1) { 'Q<8,8,1>' },
//   Set(1) { 'Q<9,2,9>' },
//   Set(1) { 'Q<9,7,4>' }
// }

// %% [markdown]
// The function `all_constraints` returns a CSP that encodes the given sudoku as a CSP.

// %%
function literalKey(lit: Literal): string {
    if (typeof lit === 'string') return lit;
    return `¬${lit[1]}`;
}

function equalClauses(c1: Clause, c2: Clause): boolean {
    if (c1.size !== c2.size) return false;
    for (const lit of c1) {
        let found = false;
        for (const l2 of c2) {
            if (literalKey(l2) === literalKey(lit)) {
                found = true;
                break;
            }
        }
        if (!found) return false;
    }
    return true;
}

function addClauseUnique(Clauses: Set<Clause>, clause: Clause) {
    for (const c of Clauses) {
        if (equalClauses(c, clause)) return; // Clause already present
    }
    Clauses.add(clause);
}

function allConstraints(): Set<Clause> {
    const L = [1, 2, 3, 4, 5, 6, 7, 8, 9];
    let Clauses = constraintsFromPuzzle();

    // Exactly one digit in every cell
    for (const row of L) {
        for (const col of L) {
            for (const clause of exactlyOneDigit(row, col)) {
                addClauseUnique(Clauses, clause);
            }
        }
    }

    // Unique entries in each row
    for (const row of L) {
        for (const clause of exactlyOnce(L.map(col => [row, col] as [number, number]))) {
            addClauseUnique(Clauses, clause);
        }
    }

    // Unique entries in each column
    for (const col of L) {
        for (const clause of exactlyOnce(L.map(row => [row, col] as [number, number]))) {
            addClauseUnique(Clauses, clause);
        }
    }

    // Unique entries in each 3x3 square
    for (let r = 0; r < 3; r++) {
        for (let c = 0; c < 3; c++) {
            const blockCells: Array<[number, number]> = [];
            for (let row = 1; row <= 3; row++) {
                for (let col = 1; col <= 3; col++) {
                    blockCells.push([r * 3 + row, c * 3 + col]);
                }
            }
            for (const clause of exactlyOnce(blockCells)) {
                addClauseUnique(Clauses, clause);
            }
        }
    }

    return Clauses;
}

// %%
const clauses = Array.from(allConstraints());

for (const clause of clauses) {
    if (clause.size === 1) {
        console.log(clause);
    }
}

for (const clause of clauses) {
    if (clause.size === 9) {
        console.log(clause);
    }
}
// Out:
// Set(1) { 'Q<1,1,8>' }
// Set(1) { 'Q<2,3,3>' }
// Set(1) { 'Q<2,4,6>' }
// Set(1) { 'Q<3,2,7>' }
// Set(1) { 'Q<3,5,9>' }
// Set(1) { 'Q<3,7,2>' }
// Set(1) { 'Q<4,2,5>' }
// Set(1) { 'Q<4,6,7>' }
// Set(1) { 'Q<5,5,4>' }
// Set(1) { 'Q<5,6,5>' }
// Set(1) { 'Q<5,7,7>' }
// Set(1) { 'Q<6,4,1>' }
// Set(1) { 'Q<6,8,3>' }
// Set(1) { 'Q<7,3,1>' }
//   'Q<8,4,2>',
//   'Q<8,4,3>',
//   'Q<8,4,4>',
//   'Q<8,4,5>',
//   'Q<8,4,6>',
//   'Q<8,4,7>',
//   'Q<8,4,8>',
//   'Q<8,4,9>'
// }
// Set(9) {
//   'Q<8,5,1>',
//   'Q<8,5,2>',
//   'Q<8,5,3>',
//   'Q<8,5,4>',
//   'Q<8,5,5>',
//   'Q<8,5,6>',
//   'Q<8,5,7>',
//   'Q<8,5,8>',
//   'Q<8,5,9>'
// }
// Set(9) {
//   'Q<8,6,1>',
//   'Q<8,6,2>',
//   'Q<8,6,3>',
//   'Q<8,6,4>',
//   'Q<8,6,5>',
//   'Q<8,6,6>',
//   'Q<8,6,7>',
//   'Q<8,6,8>',
//   'Q<8,6,9>'
// }
// Set(9) {
//   'Q<8,7,1>',
//   'Q<8,7,2>',
//   'Q<8,7,3>',
//   'Q<8,7,4>',
//   'Q<8,7,5>',
//   'Q<8,7,6>',
//   'Q<8,7,7>',
//   'Q<8,7,8>',
//   'Q<8,7,9>'
// }
// Set(9) {
//   'Q<8,8,1>',
//   'Q<8,8,2>',
//   'Q<8,8,3>',
//   'Q<8,8,4>',
//   'Q<8,8,5>',
//   'Q<8,8,6>',
//   'Q<8,8,7>',
//   'Q<8,8,8>',
//   'Q<8,8,9>'
// }
// Set(9) {
//   'Q<8,9,1>',
//   'Q<8,9,2>',
//   'Q<8,9,3>',
//   'Q<8,9,4>',
//   'Q<8,9,5>',
//   'Q<8,9,6>',
//   'Q<8,9,7>',
//   'Q<8,9,8>',
//   'Q<8,9,9>'
// }
// Set(9) {
//   'Q<9,1,1>',
//   'Q<9,1,2>',
//   'Q<9,1,3>',
//   'Q<9,1,4>',
//   'Q<9,1,5>',
//   'Q<9,1,6>',
//   'Q<9,1,7>',
//   'Q<9,1,8>',
//   'Q<9,1,9>'
// }
// Set(9) {
//   'Q<9,2,1>',
//   'Q<9,2,2>',
//   'Q<9,2,3>',
//   'Q<9,2,4>',
//   'Q<9,2,5>',
//   'Q<9,2,6>',
//   'Q<9,2,7>',
//   'Q<9,2,8>',
//   'Q<9,2,9>'
// }
// Set(9) {
//   'Q<9,3,1>',
//   'Q<9,3,2>',
//   'Q<9,3,3>',
//   'Q<9,3,4>',
//   'Q<9,3,5>',
//   'Q<9,3,6>',
//   'Q<9,3,7>',
//   'Q<9,3,8>',
//   'Q<9,3,9>'
// }
// Set(9) {
//   'Q<9,4,1>',
//   'Q<9,4,2>',
//   'Q<9,4,3>',
//   'Q<9,4,4>',
//   'Q<9,4,5>',
//   'Q<9,4,6>',
//   'Q<9,4,7>',
//   'Q<9,4,8>',
//   'Q<9,4,9>'
// }
// Set(9) {
//   'Q<9,5,1>',
//   'Q<9,5,2>',
//   'Q<9,5,3>',
//   'Q<9,5,4>',
//   'Q<9,5,5>',
//   'Q<9,5,6>',
//   'Q<9,5,7>',
//   'Q<9,5,8>',
//   'Q<9,5,9>'
// }
// Set(9) {
//   'Q<9,6,1>',
//   'Q<9,6,2>',
//   'Q<9,6,3>',
// }
// Set(9) {
//   'Q<4,1,4>',
//   'Q<4,2,4>',
//   'Q<4,3,4>',
//   'Q<4,4,4>',
//   'Q<4,5,4>',
//   'Q<4,6,4>',
//   'Q<4,7,4>',
//   'Q<4,8,4>',
//   'Q<4,9,4>'
// }
// Set(9) {
//   'Q<4,1,5>',
//   'Q<4,2,5>',
//   'Q<4,3,5>',
//   'Q<4,4,5>',
//   'Q<4,5,5>',
//   'Q<4,6,5>',
//   'Q<4,7,5>',
//   'Q<4,8,5>',
//   'Q<4,9,5>'
// }
// Set(9) {
//   'Q<4,1,6>',
//   'Q<4,2,6>',
//   'Q<4,3,6>',
//   'Q<4,4,6>',
//   'Q<4,5,6>',
//   'Q<4,6,6>',
//   'Q<4,7,6>',
//   'Q<4,8,6>',
//   'Q<4,9,6>'
// }
// Set(9) {
//   'Q<4,1,7>',
//   'Q<4,2,7>',
//   'Q<4,3,7>',
//   'Q<4,4,7>',
//   'Q<4,5,7>',
//   'Q<4,6,7>',
//   'Q<4,7,7>',
//   'Q<4,8,7>',
//   'Q<4,9,7>'
// }
// Set(9) {
//   'Q<4,1,8>',
//   'Q<4,2,8>',
//   'Q<4,3,8>',
//   'Q<4,4,8>',
//   'Q<4,5,8>',
//   'Q<4,6,8>',
//   'Q<4,7,8>',
//   'Q<4,8,8>',
//   'Q<4,9,8>'
// }
// Set(9) {
//   'Q<4,1,9>',
//   'Q<4,2,9>',
//   'Q<4,3,9>',
//   'Q<4,4,9>',
//   'Q<4,5,9>',
//   'Q<4,6,9>',
//   'Q<4,7,9>',
//   'Q<4,8,9>',
//   'Q<4,9,9>'
// }
// Set(9) {
//   'Q<5,1,1>',
//   'Q<5,2,1>',
//   'Q<5,3,1>',
//   'Q<5,4,1>',
//   'Q<5,5,1>',
//   'Q<5,6,1>',
//   'Q<5,7,1>',
//   'Q<5,8,1>',
//   'Q<5,9,1>'
// }
// Set(9) {
//   'Q<5,1,2>',
//   'Q<5,2,2>',
//   'Q<5,3,2>',
//   'Q<5,4,2>',
//   'Q<5,5,2>',
//   'Q<5,6,2>',
//   'Q<5,7,2>',
//   'Q<5,8,2>',
//   'Q<5,9,2>'
// }
// Set(9) {
//   'Q<5,1,3>',
//   'Q<5,2,3>',
//   'Q<5,3,3>',
//   'Q<5,4,3>',
//   'Q<5,5,3>',
//   'Q<5,6,3>',
//   'Q<5,7,3>',
//   'Q<5,8,3>',
//   'Q<5,9,3>'
// }
// Set(9) {
//   'Q<5,1,4>',
//   'Q<5,2,4>',
//   'Q<5,3,4>',
//   'Q<5,4,4>',
//   'Q<5,5,4>',
//   'Q<5,6,4>',
//   'Q<5,7,4>',
//   'Q<5,8,4>',
//   'Q<5,9,4>'
// }
// Set(9) {
//   'Q<5,1,5>',
//   'Q<5,2,5>',
//   'Q<5,3,5>',
//   'Q<5,4,5>',
//   'Q<5,5,5>',
//   'Q<5,6,5>',
//   'Q<5,7,5>',
//   'Q<5,8,5>',
//   'Q<5,9,5>'
// }
// Set(9) {
//   'Q<5,1,6>',
//   'Q<5,2,6>',
//   'Q<5,3,6>',
//   'Q<5,4,6>',
//   'Q<5,5,6>',
//   'Q<5,6,6>',
//   'Q<5,7,6>',
//   'Q<5,8,6>',
//   'Q<5,9,6>'
// }
// Set(9) {
//   'Q<5,1,7>',
//   'Q<5,2,7>',
//   'Q<5,3,7>',
//   'Q<5,4,7>',
//   'Q<5,5,7>',
//   'Q<5,6,7>',
//   'Q<5,7,7>',
//   'Q<5,8,7>',
//   'Q<5,9,7>'
// }
// Set(9) {
//   'Q<5,1,8>',
//   'Q<5,2,8>',
//   'Q<5,3,8>',
//   'Q<5,4,8>',
//   'Q<5,5,8>',
//   'Q<5,6,8>',
//   'Q<5,7,8>',
//   'Q<5,8,8>',
//   'Q<5,9,8>'
// }

// %%
allConstraints().size

// %% [markdown]
// The function `solve(Constraints, Variables)` receives two arguments:
// - `Constraints` is a set of formulas representing a constraint satisfaction problem.
// - `Variables`   is the set of variables that occur in this formulas.
//
// The function computes a solution to the given problem and returns this solution.

// %%
function sudoku() : Set<Set<Literal>> | null {
  const Clauses: Clause[] = Array.from(allConstraints());
  const [V2I, I2V] = numberVariables(Clauses);
  const ClausesPyco = clauses2pyco(Clauses, V2I);

  // pycosat needs to be provided or replaced with JS equivalent
  // Assuming pycosat.solve is synchronous here for compatibility
  const Solution: number[] = pycosat.solve(ClausesPyco);

  if (Solution.length !== 0) {
    return int2var(Solution, I2V);
  } else {
    console.log('The problem is not solvable!');
    return null;
  }
}
// Out:
// 4:36 - Argument of type 'Clause[]' is not assignable to parameter of type '(number | [string, number])[][]'.
// 4:36 - Type 'Clause' is not assignable to type '(number | [string, number])[]'.
// 4:36 - Type 'Literal' is not assignable to type 'number | [string, number]'.
// 4:36 - Type 'string' is not assignable to type 'number | [string, number]'.
// 8:30 - Cannot find name 'pycosat'.

// %%
9**3

// %% [markdown]
// Even though this Sudoku is modelled using $9^3 = 729$ propositional variables and we have 10551 clauses, PicoSat uses less than 40 milliseconds to solve the problem.

// %%
%%time
Solution = sudoku()

// %% [markdown]
// The function `remove_negative` removes the negative literals from the given solution `S` and returns the set of variables that have to be `True`.

// %%
def remove_negative(S):
    return { l for C in S for l in C if not l[0] == '¬'}

// %%
Solution = remove_negative(Solution)

// %%
Solution

// %% [markdown]
// ## Graphical Representation

// %% [markdown]
// The following line needs to be executed once to install the package `problem_visuals`.

// %%
!pip install git+https://github.com/reclinarka/problem_visuals

// %%
from problem_visuals.games.sudoku.grid import Grid

// %%
def arb(S):
    for x in S:
        return S

// %%
def transform_solution(Solution):
    Result = {}
    for variable in Solution:
        row   = int(variable[2:3])
        col   = int(variable[4:5])
        digit = int(variable[6:7])
        Result[f'V{row}{col}'] = digit
    return Result

// %%
transform_solution(Solution)

// %%
def show_solution(Solution, width='50%'):
    Solution = transform_solution(Solution)
    Sudoku = create_puzzle()
    for row in range(9):
        for col in range(9):
            if Sudoku[row][col] != '*':
                del Solution[f'V{row+1}{col+1}']
    return Grid(state=Sudoku, assigned=Solution, html_width=width)

// %%
show_solution(Solution)
