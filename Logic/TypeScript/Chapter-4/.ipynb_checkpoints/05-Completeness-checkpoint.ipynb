// %%
import * as tslab from "tslab";
import { readFileSync } from "fs";

const css = readFileSync("../style.css", "utf-8");
tslab.display.html(`<style>${css}</style>`);

// %%
type Variable = string;
type Literal = Variable | ['¬', Variable];
type Clause = ReadonlySet<Literal>;
type CNF = ReadonlySet<Clause>;

// %% [markdown]
// # Refutational Completeness of the Cut Rule

// %% [markdown]
// This notebook implements a number of procedures that are needed in our proof of the <em style="color:blue">refutational completeness</em> of the cut rule.

// %% [markdown]
// The function $\texttt{complement}(l)$ computes the *complement* of a literal $l$.
// As we are only dealing with formulas in CNF that are written in set notation and these formulas do not contain $\top$ or $\bot$, a literal is either
// a propositional variable or the negation of a propositional variable.
// Therefore, if $p$ is a propositional variable, we have the following:
// * $\texttt{complement}(p) = \neg p$,
// * $\texttt{complement}(\neg p) = p$.

// %%
function complement(l: Literal): Literal | null {
  if (Array.isArray(l) && l[0] === '¬') return l[1];
  if (typeof l === 'string') return ['¬', l];
  return null;
}

// %%
complement('p');

// %%
complement(['¬', 'p']);

// %% [markdown]
// The function $\texttt{extractVariable}(l)$ extracts the propositional variable from the literal $l$.
// If $p$ is a propositional variable, we have the following:
// <ol>
//     <li>$\texttt{extractVariable}(p) = p$,
//     </li>
//     <li>$\texttt{extractVariable}(\neg p) = p$.
//     </li>
// </ol>

// %%
function extractVariable(l: Literal): Variable | null {
  if (Array.isArray(l) && l[0] === '¬') return l[1];
  if (typeof l === 'string') return l;
  return null;
}

// %%
extractVariable('p');

// %%
extractVariable(['¬', 'q']);

// %% [markdown]
// The function $\texttt{collectsVariables}(M)$ takes a set of clauses $M$ as its input and computes the set of all propositional variables occurring in $M$.  The clauses in $M$ are represented as sets of literals.

// %%
function collectVariables(M: ReadonlySet<Clause>): ReadonlySet<Variable> {
  const vars = new Set<Variable>();
  for (const clause of M) {
    for (const l of clause) {
      const v = extractVariable(l);
      if (v !== null) vars.add(v);
    }
  }
  return vars;
}

// %%
const C1: Clause = new Set(['p', 'q', 'r']);
const C2: Clause = new Set([['¬', 'p'], ['¬', 'q'], ['¬', 's']]);
const M: ReadonlySet<Clause> = new Set([C1, C2]);
console.log(collectVariables(M));

// %% [markdown]
// Given two clauses $C_1$ and $C_2$ that are represented as sets of literals, the function `cutRule`$(C_1, C_2)$ computes the set of all clauses that can be derived from $C_1$ and $C_2$ using the *cut rule*.  In set notation, the cut rule is the following rule of inference:
// $$
//    \frac{\displaystyle \;C_1\cup \{l\} \quad C_2 \cup \bigl\{\overline{\,l\,}\bigr\}}{\displaystyle C_1 \cup C_2}
// $$

// %%
function cutRule(C1: Clause, C2: Clause): Set<Clause> {
  const result = new Set<Clause>();
  for (const l of C1) {
    const comp = complement(l);
    if (comp !== null && C2.has(comp)) {
      const newClause = new Set([...C1].filter(x => x !== l));
      for (const lit of C2) {
        if (lit !== comp) newClause.add(lit);
      }
      result.add(newClause);
    }
  }
  return result;
}

// %%
const C1: Clause = new Set([['¬', 'q'], ['¬', 'r']]);
const C2: Clause = new Set(['q', 'r']);
console.log(cutRule(C1, C2));

// %% [markdown]
// The function `literalToString` converts a literal to its string form.
// Simple literals (strings) return as is, negated literals (arrays) are joined into a string.

// %%
function literalToString(l: Literal): string {
  return typeof l === 'string' ? l : l.join('');
}

// %% [markdown]
// The function `stringToLiteral` converts a string back to a literal.
// Strings starting with '¬' are parsed as negated literals, otherwise as simple literals.

// %%
function stringToLiteral(s: string): Literal {
  if (s.startsWith('¬')) return ['¬', s.substring(1)];
  return s;
}

// %% [markdown]
// The function `normalizeClause` converts a clause (set of literals) to a string uniquely representing it.
// Sorting literals ensures the same clause structure always yields the same string.

// %%
function normalizeClause(clause: Clause): Clause {
  const litStrings = [...clause].map(literalToString);
  const uniqueLitStrings = Array.from(new Set(litStrings)).sort();
  return new Set(uniqueLitStrings.map(stringToLiteral)) as Clause;
}

// %% [markdown]
// The function `clauseToString` converts a clause (set of literals) to a string uniquely representing it.
// Sorting literals ensures the same clause structure always yields the same string.

// %%
function clauseToString(clause: Clause): string {
  return [...clause].map(lit => 
    typeof lit === 'string' ? lit : lit.join('')
  ).sort().join(',');
}

// %% [markdown]
// In the expression `saturate(Clauses)` below, `Clauses` is a set of *clauses*, where each clause is a set of *literals*.  The call `saturate(Clauses)` computes the set of all clauses that can be derived from clauses in the set `Clauses` using the *cut rule*.  The function keeps applying the cut rule until either no new clauses can be derived, or the empty clause $\{\}$ is derived.  The resulting set of clauses is *saturated* in the following sense:  If $C_1$ and $C_2$ are clauses from the set `Clauses` and the clause $D$ can be derived from $C_1$ and $C_2$ via the cut rule, then $D \in \texttt{Clauses}$ or $\{\} \in \texttt{Clauses}$.

// %%
function saturate(Clauses: Set<Clause>): Set<Clause> {
  const clauseStrings = new Set<string>();
  let currentClauses = new Set<Clause>();
  for (const c of Clauses) {
    const norm = normalizeClause(c);
    currentClauses.add(norm);
    clauseStrings.add(clauseToString(norm));
  }
  while (true) {
    const Derived = new Set<Clause>();
    const derivedStrings = new Set<string>();
    for (const C1 of currentClauses) {
      for (const C2 of currentClauses) {
        for (const C of cutRule(C1, C2)) {
          const normC = normalizeClause(C);
          const cStr = clauseToString(normC);
          if (!clauseStrings.has(cStr) && !derivedStrings.has(cStr)) {
            Derived.add(normC);
            derivedStrings.add(cStr);
          }
        }
      }
    }
    if ([...Derived].some(c => c.size === 0)) {
      return new Set([new Set()]);
    }
    if (Derived.size === 0) {
      return currentClauses;
    }
    for (const c of Derived) {
      const cStr = clauseToString(c);
      clauseStrings.add(cStr);
      currentClauses.add(c);
    }
  }
}
function clauseToString(clause: Clause): string {
  return [...clause].map(lit => 
    typeof lit === 'string' ? lit : lit.join('')
  ).sort().join(',');
}

// %%
const C1: Clause = new Set(['p', 'q']);
const C2: Clause = new Set([['¬', 'p']]);
const C3: Clause = new Set([['¬', 'p'], ['¬', 'q']]);
const Clauses: Set<Clause> = new Set([C1, C2, C3]);
console.log(saturate(Clauses));

// %% [markdown]
// The function $\texttt{findValuation}(\texttt{Clauses})$ takes a set of clauses as input.  The function tries to compute a variable interpretation that makes all of these clauses `True`.  If this attempt is successful, a set of literals is returned.  This set of literals does not contain  any complementary literals and therefore corresponds to a variable assignment satisfying all clauses.  If $\texttt{Clauses}$ is unsatisfiable, `False` is returned.

// %%
function findValuation(Clauses: Set<Clause>): false | Set<Literal> {
  const Variables = collectVariables(Clauses);
  const saturatedClauses = saturate(new Set(Clauses));
  if ([...saturatedClauses].some(c => c.size === 0)) return false;
  const Literals = new Set<Literal>();
  for (const p of Variables) {
    const compLiterals = new Set<Literal>();
    for (const l of Literals) {
      const comp = complement(l);
      if (comp !== null) compLiterals.add(comp);
    }
    let satisfies = false;
    for (const C of saturatedClauses) {
      if (C.has(p as Literal)) {
        let restIsComplement = true;
        for (const l of C) {
          if (l !== (p as Literal) && !compLiterals.has(l)) {
            restIsComplement = false;
            break;
          }
        }
        if (restIsComplement) {
          satisfies = true;
          break;
        }
      }
    }
    if (satisfies) Literals.add(p as Literal);
    else Literals.add(['¬', p]);
  }
  return Literals;
}

// %%
const C01: Clause = new Set(['r', 'p', 's']);
const C02: Clause = new Set(['r', 's']);
const C03: Clause = new Set(['p', 'q', 's']);
const C04: Clause = new Set([['¬', 'p'], ['¬', 'q']]);
const C05: Clause = new Set([['¬', 'p'], 's', ['¬', 'r']]);
const C06: Clause = new Set(['p', ['¬', 'q'], 'r']);
const C07: Clause = new Set([['¬', 'r'], ['¬', 's'], 'q']);
const C08: Clause = new Set([['¬', 'p'], ['¬', 's']]);
const C09: Clause = new Set(['p', ['¬', 'r'], ['¬', 'q']]);
const C10: Clause = new Set([['¬', 'p'], 'r', 'q', ['¬', 's']]);
const C11: Clause = new Set(['p', 'q', 'r', ['¬', 's']]);
const Clauses: Set<Clause> = new Set([C01, C02, C03, C04, C05, C06, C07, C08, C09, C10]);

const valuation = findValuation(Clauses);
console.log(valuation);

// %%
const Clauses: Set<Clause> = new Set([C01, C02, C03, C04, C05, C06, C07, C08, C09, C10, C11]);

const valuation = findValuation(Clauses);
console.log(valuation);

// %%
saturate(Clauses)
