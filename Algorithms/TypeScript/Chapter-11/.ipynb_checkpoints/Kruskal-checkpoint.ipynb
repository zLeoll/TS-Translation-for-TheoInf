// %%
import * as tslab from "tslab";
import { readFileSync } from "fs";

const css = readFileSync("../style.css", "utf-8");
tslab.display.html(`<style>${css}</style>`);

// %% [markdown]
// # Kruskal's Algorithm for Computing the Minimum Spanning Tree

// %% [markdown]
// In our implementation of [Kruskal's algorithm](https://en.wikipedia.org/wiki/Kruskal%27s_algorithm) for finding the
// *minimum spanning tree* we use the *union-find* data structure that we have defined previously.

// %%
import { Node, union } from './UnionFindOO';

// %% [markdown]
// Furthermore, we need a priority queue. The module `heapq` implements a priority queue.  The part
// of the API from this module that we utilize is the following:
// - `H.heappush(x)` pushes `x` onto the heap `H`,
// - `H.heappop()`   removes the smallest element from the heap `H` and returns this element,
// - `H = []`        creates an empty heap.

// %%
import { Heap } from "heap-js";
import { Graphviz } from "@hpcc-js/wasm";
import { display } from "tslab"
import * as fs from 'fs';

// %% [markdown]
// The function $\texttt{mst}(V, E)$ takes a set of *nodes* $V$ and a set of *weighted edges* $E$ to compute a minimum spanning tree.  It is assumed that the pair $(V, E)$ represents a *weighted graph* $G$ that is *connected*.  The weighted edges in the set $E$ have the form
// $$ \bigl\langle w, \langle x, y\rangle\bigr\rangle.  $$
// Here, $x$ and $y$ are nodes from the set $V$, while $w$ is the cost of the edge $\{x,y\}$.
//
// The function call `mst(V, E)` returns a set of weighted edges that define a [minimum spanning tree](https://en.wikipedia.org/wiki/Minimum_spanning_tree)
// of the weighted graph $G$. The function `mst` does **not** check whether $G$ is connected.

// %%
type Edge = [number, [number, number]];
function mst(V: number[], E: Edge[]): Set<Edge> | null {

    const Nodes: { [x: number]: Node } = {};
    for (const x of V) {
        Nodes[x] = new Node(x);
    }

    const MST: Set<Edge> = new Set();
    const H: Edge[] = E.slice().sort((a, b) => a[0] - b[0]);

    while (true) {
        if (H.length === 0) {
            return null;
        }
        const edge = H.shift()!;
        const [w, [x, y]] = edge;
        const root_x = Nodes[x].find();
        const root_y = Nodes[y].find();
        if (root_x !== root_y) {
            MST.add(edge);
            union(Nodes[x], Nodes[y]);
            if (MST.size === V.length - 1) {
                return MST;
            }
        }
    }
}

// %%
def mst(V, E):
    Nodes = { x: Node(x) for x in V }
    MST = set()         # minimum spanning tree, represented as set of weighted edges
    H   = []            # empty priority queue for weighted edges
    for edge in E:
        hq.heappush(H, edge)
    while True:
        if H == []:
            return None # the graph is not connected
        w, (x, y) = hq.heappop(H)
        root_x = Node[x].find()
        root_y = Node[y].find()
        if root_x != root_y:
            MST.add((w, (x, y)))
            union(Node[x], Node[y])
            if len(MST) == len(V) - 1:
                return MST

// %% [markdown]
// The implementation of `mst` that is given below traces its computation via `graphviz`.

// %%
async function mst(V: number[], E: Edge[]): Promise<Set<Edge> | null> {
    // Lade die Graphviz WASM-Instanz
    const graphviz = await Graphviz.load();

    // Zeige den kompletten Graph am Anfang an
    const initialDot = toDot(E);
    const initialSvg = graphviz.layout(initialDot, "svg", "dot");
    display.html(initialSvg);

    // Initialisiere die Knoten
    const Nodes: { [x: number]: Node } = {};
    for (const x of V) {
        Nodes[x] = new Node(x);
    }

    const MST: Set<Edge> = new Set();
    const H: Edge[] = E.slice().sort((a, b) => a[0] - b[0]);

    while (true) {
        if (H.length === 0) {
            return null;
        }
        const edge = H.shift()!;
        const [w, [x, y]] = edge;

        console.log(`testing ${x} - ${y}, weight ${w}`);

        const root_x = Nodes[x].find();
        const root_y = Nodes[y].find();

        if (root_x !== root_y) {
            console.log(`connect ${x} - ${y}`);
            MST.add(edge);
            union(Nodes[x], Nodes[y]);

            // Zeige aktuellen MST
            const mstDot = toDot(E, MST);
            const mstSvg = graphviz.layout(mstDot, "svg", "dot");
            display.html(mstSvg);

            console.log('_'.repeat(120));
            if (MST.size === V.length - 1) {
                return MST;
            }
        }
    }
}

// %%
def mst(V, E):
    display(toDot(E)) # display the given graph
    Nodes = { x: Node(x) for x in V }
    MST   = set()         # minimum spanning tree, represented as set of weighted edges
    H     = []            # empty priority queue for weighted edges
    for edge in E:
        hq.heappush(H, edge)
    while True:
        if H == []:
            return None # the graph is not connected
        w, (x, y) = hq.heappop(H)
        print(f'testing {x} - {y}, weight {w}')
        root_x = Nodes[x].find()
        root_y = Nodes[y].find()
        if root_x != root_y:
            print(f'connect {x} - {y}')
            MST.add((w, (x, y)))
            union(Nodes[x], Nodes[y])
            display(toDot(E, MST))
            print('_' * 120)
            if len(MST) == len(V) - 1:
                return MST

// %% [markdown]
// Given a set $E$ of weighted edges, the function $\texttt{toDot}$ transforms this set into a dot structure that can be displayed as a graph.  The edges that are present in the set $H$ are assumed to be the edges that are part of the minimum spanning tree and therefore are highlighted.

// %%
function toDot(E: Edge[], MST: Set<Edge> = new Set()): string {
    const V = new Set<number>();
    for (const [, [x, y]] of E) {
        V.add(x);
        V.add(y);
    }

    let dot = 'graph G {\n  rankdir=LR;\n';
    for (const x of V) {
        dot += `  ${x};\n`;
    }
    for (const [w, [x, y]] of E) {
        let inMST = false;
        for (const [mw, [mx, my]] of MST) {
            if (w === mw && ((x === mx && y === my) || (x === my && y === mx))) {
                inMST = true;
                break;
            }
        }
        if (inMST)
            dot += `  ${x} -- ${y} [label="${w}", color="blue", penwidth=2];\n`;
        else
            dot += `  ${x} -- ${y} [label="${w}", style="dashed"];\n`;
    }
    dot += '}';
    return dot;
}

// %%
def toDot(E, H=set()):
    V = set()
    for (_, (x, y)) in E:
        V.add(x)
        V.add(y)
    dot = gv.Graph()
    dot.attr(rankdir='LR')
    for x in V:
        dot.node(str(x))
    for (w, (x, y)) in E:
        if (w, (x, y)) in H:
            dot.edge(str(x), str(y), label=str(w), color='blue', penwidth='2')
        else:
            dot.edge(str(x), str(y), label=str(w), style='dashed')
    return dot

// %% [markdown]
// The file `tiny.txt` contains the description of a weighted graph.  Every line in this file has the form:
// ```
// x y w
// ```
// Here `x` and `y` are numbers specifying nodes, while `w` is the weight of this node.  The code given below displays the file `tiny.txt`.

// %%
const s = fs.readFileSync('tiny.txt', 'utf-8');
console.log(s);
// Out:
// 4 5 3
// 4 7 4
// 5 7 2
// 0 7 1
// 1 5 6
// 0 4 4
// 2 3 2
// 1 7 2
// 0 2 3
// 1 2 4
// 1 3 3
// 2 7 3
// 6 2 4
// 3 6 5
// 6 0 6
// 6 4 7
// 7 8 2
// 8 1 5

// %%
with open('tiny.txt', 'r') as f:
    s = f.read()
print(s)

// %% [markdown]
// The function `demoFile(fn)` takes a filename `fn` as its argument. The corresponding file is expected to hold the description of
// an *undirected weighted graph*.  The function computes the minimum spanning tree for this graph.

// %%
async function demoFile(fn: string): Promise<string | undefined> {
    const text = await fs.promises.readFile(fn, 'utf-8');
    const data = text.split('\n').filter(line => line.trim() !== '');

    const Edges: Set<Edge> = new Set();
    const Nodes: Set<number> = new Set();

    for (const line of data) {
        const [xStr, yStr, weightStr] = line.split(/\s+/);
        const x = parseInt(xStr), y = parseInt(yStr), weight = parseInt(weightStr);
        Edges.add([weight, [x, y]]);
        Nodes.add(x);
        Nodes.add(y);
    }

    const NodesArr = Array.from(Nodes);
    const EdgesArr = Array.from(Edges);

    // Korrigiert: warte auf das Set<Edge> Resultat!
    const MST = await mst(NodesArr, EdgesArr);
    console.log(MST);

    if (MST) {
        return toDot(EdgesArr, MST);
    }
}

// %%
def demoFile(fn):
    with open(fn, 'r') as file:
        data = file.readlines()
    Edges = set()
    Nodes = set()
    for line in data:
        x, y, weight = line.split()
        x, y, weight = int(x), int(y), int(weight)
        Edges.add((weight, (x, y)))
        Nodes.add(x)
        Nodes.add(y)
    MST = mst(Nodes, Edges);
    print(MST)
    if MST:
        return toDot(Edges, MST)

// %%
const MSTDot = await demoFile('tiny.txt');
MSTDot
// Out:
// <?xml version="1.0" encoding="UTF-8" standalone="no"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Generated by graphviz version 14.0.1 (0)
//  -->
// <!-- Title: G Pages: 1 -->
// <svg width="838pt" height="277pt"
//  viewBox="0.00 0.00 838.00 277.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 272.66)">
// <title>G</title>
// <polygon fill="white" stroke="none" points="-4,4 -4,-272.66 834,-272.66 834,4 -4,4"/>
// <!-- 4 -->
// <g id="node1" class="node">
// <title>4</title>
// <ellipse fill="none" stroke="black" cx="27" cy="-69" rx="27" ry="18"/>
// <text xml:space="preserve" text-anchor="middle" x="27" y="-64.8" font-family="Times,serif" font-size="14.00">4</text>
// </g>
// <!-- 5 -->
// <g id="node2" class="node">
// <title>5</title>
// <ellipse fill="none" stroke="black" cx="124" cy="-145" rx="27" ry="18"/>
// <text xml:space="preserve" text-anchor="middle" x="124" y="-140.8" font-family="Times,serif" font-size="14.00">5</text>
// </g>
// <!-- 4&#45;&#45;5 -->
// <g id="edge1" class="edge">
// <title>4&#45;&#45;5</title>
// <path fill="none" stroke="black" stroke-dasharray="5,2" d="M44.15,-82.89C52.41,-89.91 62.66,-98.51 72,-106 82.96,-114.79 95.48,-124.37 105.38,-131.84"/>
// <text xml:space="preserve" text-anchor="middle" x="75.5" y="-115.63" font-family="Times,serif" font-size="14.00">3</text>
// </g>
// <!-- 7 -->
// <g id="node3" class="node">
// <title>7</title>
// <ellipse fill="none" stroke="black" cx="221" cy="-137" rx="27" ry="18"/>
// <text xml:space="preserve" text-anchor="middle" x="221" y="-132.8" font-family="Times,serif" font-size="14.00">7</text>
// </g>
// <!-- 4&#45;&#45;7 -->
// <g id="edge2" class="edge">
// <title>4&#45;&#45;7</title>
// <path fill="none" stroke="black" stroke-dasharray="5,2" d="M53.49,-73.94C78.73,-79.23 118.24,-88.6 151,-101.2 168.13,-107.79 186.53,-117.48 200.02,-125.12"/>
// <text xml:space="preserve" text-anchor="middle" x="124" y="-105.4" font-family="Times,serif" font-size="14.00">4</text>
// </g>
// <!-- 5&#45;&#45;7 -->
// <g id="edge3" class="edge">
// <title>5&#45;&#45;7</title>
// <path fill="none" stroke="black" stroke-dasharray="5,2" d="M151.21,-142.79C164.5,-141.67 180.6,-140.32 193.87,-139.2"/>
// <text xml:space="preserve" text-anchor="middle" x="172.5" y="-145.44" font-family="Times,serif" font-size="14.00">2</text>
// </g>
// <!-- 8 -->
// <g id="node9" class="node">
// <title>8</title>
//
title>
// <path fill="none" stroke="black" stroke-dasharray="5,2" d="M778.95,-168.34C772.27,-170.48 764.91,-172.58 758,-174 679.51,-190.14 584.57,-195.51 539.38,-197.23"/>
// <text xml:space="preserve" text-anchor="middle" x="657.5" y="-193.37" font-family="Times,serif" font-size="14.00">2</text>
// </g>
// <!-- 6 -->
// <g id="node8" class="node">
// <title>6</title>
// <ellipse fill="none" stroke="black" cx="609" cy="-110" rx="27" ry="18"/>
// <text xml:space="preserve" text-anchor="middle" x="609" y="-105.8" font-family="Times,serif" font-size="14.00">6</text>
// </g>
// <!-- 3&#45;&#45;6 -->
// <g id="edge14" class="edge">
// <title>3&#45;&#45;6</title>
// <path fill="none" stroke="black" stroke-dasharray="5,2" d="M528.69,-183.47C546.29,-167.16 574.68,-140.87 592.29,-124.55"/>
// <text xml:space="preserve" text-anchor="middle" x="560.5" y="-160.84" font-family="Times,serif" font-size="14.00">5</text>
// </g>
// <!-- 6&#45;&#45;4 -->
// <g id="edge16" class="edge">
// <
// testing 0 - 7, weight 1
// connect 0 - 7
// <?xml version="1.0" encoding="UTF-8" standalone="no"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Generated by graphviz version 14.0.1 (0)
//  -->
// <!-- Title: G Pages: 1 -->
// <svg width="838pt" height="277pt"
//  viewBox="0.00 0.00 838.00 277.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 272.66)">
// <title>G</title>
// <polygon fill="white" stroke="none" points="-4,4 -4,-272.66 834,-272.66 834,4 -4,4"/>
// <!-- 4 -->
// <g id="node1" class="node">
// <title>4</title>
// <ellipse fill="none" stroke="black" cx="27" cy="-69" rx="27" ry="18"/>
// <text xml:space="preserve" text-anchor="middle" x="27" y="-64.8" font-family="Times,serif" font-size="14.00">4</text>
// </g>
// <!-- 5 -->
// <g id="node2" class="node">
// <title>5</title>
// <ellipse fill="none" stroke="black" cx="124" cy="-145" rx="27" ry="18"/>
// <text xml:space="preserve" text-anchor="middle" x="124" y="-140.8" font-family="Times,serif" font-size="14.00">5</text>
// </g>
// <!-- 4&#45;&#45;5 -->
// <g id="edge1" class="edge">
// <title>4&#45;&#45;5</title>
// <path fill="none" stroke="black" stroke-dasharray="5,2" d="M44.15,-82.89C52.41,-89.91 62.66,-98.51 72,-106 82.96,-114.79 95.48,-124.37 105.38,-131.84"/>
// <text xml:space="preserve" text-anchor="middle" x="75.5" y="-115.63" font-family="Times,serif" font-size="14.00">3</text>
// </g>
// <!-- 7 -->
// <g id="node3" class="node">
// <title>7</title>
// <ellipse fill="none" stroke="black" cx="221" cy="-137" rx="27" ry="18"/>
// <text xml:space="preserve" text-anchor="middle" x="221" y="-132.8" font-family="Times,serif" font-size="14.00">7</text>
// </g>
// <!-- 4&#45;&#45;7 -->
// <g id="edge2" class="edge">
// <title>4&#45;&#45;7</title>
// <path fill="none" stroke="black" stroke-dasharray="5,2" d="M53.49,-73.94C78.73,-79.23 118.24,-88.6 151,-101.2 168.13,-107.79 186.53,-117.48 200.02,-125.12"/>
// <text xml:space="preserve" text-anchor="middle" x="124" y="-105.4" font-family="Times,serif" font-size="14.00">4</text>
// </g>
// <!-- 5&#45;&#45;7 -->
// <g id="edge3" class="edge">
// <title>5&#45;&#45;7</title>
// <path fill="none" stroke="black" stroke-dasharray="5,2" d="M151.21,-142.79C164.5,-141.67 180.6,-140.32 193.87,-139.2"/>
// <text xml:space="preserve" text-anchor="middle" x="172.5" y="-145.44" font-family="Times,serif" font-size="14.00">2</text>
// </g>
// <!-- 8 -->
// <g id="node9" class="node">
// <title>8</title>
// <ellipse fill="none" stroke="black" cx="318" cy="-232" rx="27" ry="18"/>
// <text xml:space="preserve" text-anchor="middle" x="318" y="-227.8" font-family="Times,serif" font-size="14.00">8</text>
// </g>
// <!-- 7&#45;&#45;8 -->
// <g id="edge17" class="edge">
// <title>7&#45;&#45;8</title>
// <path fill="none" stroke="black" stroke-dasharray="5,2" d="M232.97,-153.09C241.33,-164.79 253.5,-180.67 266,-193 275.84,-202.71 288.11,-212.16 298.15,-219.33"/>
// <text xml:space="preserve" text-anchor="middle" x="269.5" y="-203.16" font-family="Times,serif" font-size="14.00">2</text>
// </g>
// <!-- 0 -->
// <g id="node4" class="node">
// <title>0</title>
// <ellipse fill="none" stroke="black" cx="706" cy="-58" rx="27" ry="18"/>
// <text xml:space="preserve" text-anchor="middle" x="706" y="-53.8" font-family="Times,serif" font-size="14.00">0</text>
// </g>
// <!-- 0&#45;&#45;4 -->
// <g id="edge6" class="edge">
// <title>0&#45;&#45;4</title>
// <path fill="none" stroke="black" stroke-dasharray="5,2" d="M691.16,-42.76C673.96,-25.58 642.85,0 610,0 123,0 123,0 123,0 87.33,0 56.03,-32.24 39.8,-52.65"/>
// <text xml:space="preserve" text-anchor="middle" x="366.5" y="-4.2" font-family="Times,serif" font-size="14.00">4</text>
// </g>
// <!-- 0&#45;&#45;7 -->
// <g id="edge4" class="edge">
// <title>0&#45;&#45;7</title>
// <path fill="none" stroke="blue" stroke-width="2" d="M678.82,-59.35C610.05,-63.39 419.05,-77.76 266,-119 258.51,-121.02 250.59,-123.98 243.56,-126.92"/>
// <text xml:space="preserve" text-anchor="middle" x="463.5" y="-85" font-family="Times,serif" font-size="14.00">1</text>
// </g>
// <!-- 2 -->
// <g id="node6" class="node">
// <title>2</title>
// <ellipse fill="none" stroke="black" cx="803" cy="-160" rx="27" ry="18"/>
// <text xml:space="preserve" text-anchor="middle" x="803" y="-155.8" font-family="Times,serif" font-size="14.00">2</text>
// </g>
// <!-- 
rx="27" ry="18"/>
// <text xml:space="preserve" text-anchor="middle" x="609" y="-105.8" font-family="Times,serif" font-size="14.00">6</text>
// </g>
// <!-- 3&#45;&#45;6 -->
// <g id="edge14" class="edge">
// <title>3&#45;&#45;6</title>
// <path fill="none" stroke="black" stroke-dasharray="5,2" d="M528.69,-183.47C546.29,-167.16 574.68,-140.87 592.29,-124.55"/>
// <text xml:space="preserve" text-anchor="middle" x="560.5" y="-160.84" font-family="Times,serif" font-size="14.00">5</text>
// </g>
// <!-- 6&#45;&#45;4 -->
// <g id="edge16" class="edge">
// <title>6&#45;&#45;4</t
// ________________________________________________________________________________________________________________________
// testing 1 - 7, weight 2
// connect 1 - 7
// <?xml version="1.0" encoding="UTF-8" standalone="no"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Generated by graphviz version 14.0.1 (0)
//  -->
// <!-- Title: G Pages: 1 -->
// <svg width="838pt" height="277pt"
//  viewBox="0.00 0.00 838.00 277.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 272.66)">
// <title>G</title>
// <polygon fill="white" stroke="none" points="-4,4 -4,-272.66 834,-272.66 834,4 -4,4"/>
// <!-- 4 -->
// <g id="node1" class="node">
// <title>4</title>
// <ellipse fill="none" stroke="black" cx="27" cy="-69" rx="27" ry="18"/>
// <text xml:space="preserve" text-anchor="middle" x="27" y="-64.8" font-family="Times,serif" font-size="14.00">4</text>
// </g>
// <!-- 5 -->
// <g id="node2" class="node">
// <title>5</title>
// <ellipse fill="none" stroke="black" cx="124" cy="-145" rx="27" ry="18"/>
// <text xml:space="preserve" text-anchor="middle" x="124" y="-140.8" font-family="Times,serif" font-size="14.00">5</text>
// </g>
// <!-- 4&#45;&#45;5 -->
// <g id="edge1" class="edge">
// <title>4&#45;&#45;5</title>
// <path fill="none" stroke="black" stroke-dasharray="5,2" d="M44.15,-82.89C52.41,-89.91 62.66,-98.51 72,-106 82.96,-114.79 95.48,-124.37 105.38,-131.84"/>
// <text xml:space="preserve" text-anchor="middle" x="75.5" y="-115.63" font-family="Times,serif" font-size="14.00">3</text>
// </g>
// <!-- 7 -->
// <g id="node3" class="node">
// <title>7</title>
// <ellipse fill="none" stroke="black" cx="221" cy="-137" rx="27" ry="18"/>
// <text xml:space="preserve" text-anchor="middle" x="221" y="-132.8" font-family="Times,serif" font-size="14.00">7</text>
// </g>
// <!-- 4&#45;&#45;7 -->
// <g id="edge2" class="edge">
// <title>4&#45;&#45;7</title>
// <path fill="none" stroke="black" stroke-dasharray="5,2" d="M53.49,-73.94C78.73,-79.23 118.24,-88.6 151,-101.2 168.13,-107.79 186.53,-117.48 200.02,-125.12"/>
// <text xml:space="preserve" text-anchor="middle" x="124" y="-105.4" font-family="Times,serif" font-size="14.00">4</text>
// </g>
// <!-- 5&#45;&#45;7 -->
// <g id="edge3" class="edge">
// <title>5&#45;&#45;7</title>
// <path fill="none" stroke="blue" stroke-width="2" d="M151.21,-142.79C164.5,-141.67 180.6,-140.32 193.87,-139.2"/>
// <text xml:space="preserve" text-anchor="middle" x="172.5" y="-145.44" font-family="Times,serif" font-size="14.00">2</text>
// </g>
// <!-- 8 -->
// <g id="node9" class="node">
// <title>8</title>
// <ellipse fill="none" stroke="black" cx="318" cy="-232" rx="27" ry="18"/>
// <text xml:space="preserve" text-anchor="middle" x="318" y="-227.8" font-family="Times,serif" font-size="14.00">8</text>
// </g>
// <!-- 7&#45;&#45;8 -->
// <g id="edge17" class="edge">
// <title>7&#45;&#45;8</title>
// <path fill="none" stroke="black" stroke-dasharray="5,2" d="M232.97,-153.09C241.33,-164.79 253.5,-180.67 266,-193 275.84,-202.71 288.11,-212.16 298.15,-219.33"/>
// <text xml:space="preserve" text-anchor="middle" x="269.5" y="-203.16" font-family="Times,serif" font-size="14.00">2</text>
// </g>
// <!-- 0 -->
// <g id="node4" class="node">
// <title>0</title>
// <ellipse fill="none" stroke="black" cx="706" cy="-58" rx="27" ry="18"/>
// <text xml:space="preserve" text-anchor="middle" x="706" y="-53.8" font-family="Times,serif" font-size="14.00">0</text>
// </g>
// <!-- 0&#45;&#45;4 -->
// <g id="edge6" class="edge">
// <title>0&#45;&#45;4</title>
// <path fill="none" stroke="black" stroke-dasharray="5,2" d="M691.16,-42.76C673.96,-25.58 642.85,0 610,0 123,0 123,0 123,0 87.33,0 56.03,-32.24 39.8,-52.65"/>
// <text xml:space="preserve" text-anchor="middle" x="366.5" y="-4.2" font-family="Times,serif" font-size="14.00">4</text>
// </g>
// <!-- 0&#45;&#45;7 -->
// <g id="edge4" class="edge">
// <title>0&#45;&#45;7</title>
// <path fill="none" stroke="blue" stroke-width="2" d="M678.82,-59.35C610.05,-63.39 419.05,-77.76 266,-119 258.51,-121.02 250.59,-123.98 243.56,-126.92"/>
// <text xml:space="preserve" text-anchor="middle" x="463.5" y="-85" font-family="Times,serif" font-size="14.00">1</text>
// </g>
// <!-- 2 -->
// <g id="node6" class="node">
// <title>2</title>
// <ellipse fill="none" stroke="black" cx="803" cy="-160" rx="27" ry="18"/>
// <text xml:space="preserve" text-anchor="middle" x="803" y="-155.8" font-family="Times,serif" font-size="14.00">2</text>
// </g>
// <!-- 0&#45;&#45;2 -->
// <g id="edge9" class="edge">
// <title>0&#45;&#45;2</title>
// <path fill="none" stroke="black" stroke-dasharray="5,2" d="M730.1,-66.49C739.53,-70.76 750.06,-76.66 758,-84.2 775.43,-100.76 788.11,-125.75 795.26,-142.46"/>
// <text xml:space="preserve" text-anchor="middle" x="754.5" y="-88.4" font-family="Times,serif" font-size="14.00">3</text>
// </g>
// <!-- 
font-family="Times,serif" font-size="14.00">3</text>
// </g>
// <!-- 7 -->
// <g id="node3" class="node">
// <title>7</title>
// <ellipse fill="none" stroke="black" cx="221" cy="-137" rx="27" ry="18"/>
// <text xml:space="preserve" text-anchor="middle" x="221" y="-132.8" font-family="Times,serif" font-size="14.00">7</text>
// </g>
// <!-- 4&#45;&#45;7 -->
// <g id="edge2" class="edge">
// <title>4&#45;&#45;7</title>
// <path fill="none" stroke="black" stroke-dasharray="5,2" d="M53.49,-73.94C78.73,-79.23 118.24,-88.6 151,-101.2 168.13,-107.79 186.53,-117.48 200.02,-125.12"/>
// <text xml:space="preserve" text-anchor="middle" x="124" y="-105.4" font-family="Times,serif" font-size="14.00">4</text>
// </g>
// <!-- 5&#45;&#45;7 -->
// <g id="edge3" class="edge">
// <title>5&#45;&#45;7</title>
// <path fill="none" stroke="blue" stroke-width="2" d="M151.21,-142.79C164.5,-141.67 180.6,-140.32 193.87,-139.2"/>
// <text xml:space="preserve" text-anchor="middle" x="172.5" y="-145.44" font-family="Times,serif" font-size="14.00">2</text>
// </g>
// <!-- 8 -->
// <g id="node9" class="node">
// <title>8</title>
// <ellipse fill="none" stroke="black" cx="318" cy="-232" rx="27" ry="18"/>
// <text xml:space="preserve" text-anchor="middle" x="318" y="-227.8" font-family="Times,serif" font-size="14.00">8</text>
// </g>
// <!-- 7&#45;&#45;8 -->
// <g id="edge17" class="edge">
// <title>7&#45;&#45;8</title>
// <path fill="none" stroke="blue" stroke-width="2" d="M232.97,-153.09C241.33,-164.79 253.5,-180.67 266,-193 275.84,-202.71 288.11,-212.16 298.15,-219.33"/>
// <text xml:space="preserve" text-anchor="middle" x="269.5" y="-203.16" font-family="Times,serif" font-size="14.00">2</text>
// </g>
// <!-- 0 -->
// <g id="node4" class="node">
// <title>0</title>
// <ellipse fill="none" stroke="black" cx="706" cy="-58" rx="27" ry="18"/>
// <text xml:space="preserve" text-anchor="middle" x="706" y="-53.8" font-family="Times,serif" font-size="14.00">0</text>
// </g>
// <!-- 0&#45;&#45;4 -->
// <g id="edge6" class="edge">
// <title>0&#45;&#45;4</title>
// <path fill="none" stroke="black" stroke-dasharray="5,2" d="M691.16,-42.76C673.96,-25.58 642.85,0 610,0 123,0 123,0 123,0 87.33,0 56.03,-32.24 39.8,-52.65"/>
// <text xml:space="preserve" text-anchor="middle" x="366.5" y="-4.2" font-family="Times,serif" font-size="14.00">4</text>
// </g>
// <!-- 0&#45;&#45;7 -->
// <g id="edge4" class="edge">
// <title>0&#45;&#45;7</title>
// <path fill="none" stroke="blue" stroke-width="2" d="M678.82,-59.35C610.05,-63.39 419.05,-77.76 266,-119 258.51,-121.02 250.59,-123.98 243.56,-126.92"/>
// <text xml:space="preserve" text-anchor="middle" x="463.5" y="-85" font-family="Times,serif" font-size="14.00">1</text>
// </g>
// <!-- 2 -->
// <g id="node6" class="node">
// <title>2</title>
// <ellipse fill="none" stroke="black" cx="803" cy="-160" rx="27" ry="18"/>
// <text xml:space="preserve" text-anchor="middle" x="803" y="-155.8" font-family="Times,serif" font-size="14.00">2</text>
// </g>
// <!-- 0&#45;&#45;2 -->
// <g id="edge9" class="edge">
// <title>0&#45;&#45;2</title>
// <path fill="none" stroke="black" stroke-dasharray="5,2" d="M730.1,-66.49C739.53,-70.76 750.06,-76.66 758,-84.2 775.43,-100.76 788.11,-125.75 795.26,-142.46"/>
// <text xml:space="preserve" text-anchor="middle" x="754.5" y="-88.4" font-family="Times,serif" font-size="14.00">3</text>
// </g>
// <!-- 1 -->
// <g id="node5" class="node">
// <title>1</title>
// <ellipse fill="none" stroke="black" cx="415" cy="-232" rx="27" ry="18"/>
// <text xml:space="preserve" text-anchor="middle" x="415" y="-227.8" font-family="Times,serif" font-size="14.00">1</text>
// </g>
// <!-- 1&#45;&#45;5 -->
// <g id="edge5" class="edge">
// <title>1&#45;&#45;5</title>
// <path fill="none" stroke="black" stroke-dasharray="5,2" d="M393.34,-242.96C386.1,-246.5 377.82,-250.23 370,-253 336.81,-264.76 324.63,-269.44 291,-259 227.56,-239.31 166.85,-186.05 139.76,-159.9"/>
// <text xml:space="preserve" text-anchor="middle" x="269.5" y="-256.06" font-family="Times,serif" font-size="14.00">6</text>
// </g>
// <!-- 1&#45;&#45;7 -->
// <g id="edge8" class="edge">
// <title>1&#45;&#45;7</title>
// <path fill="none" stroke="blue" stroke-width="2" d="M395.48,-219.02C381.87,-209.79 362.75,-197.44 345,-188.2 311.35,-170.68 270.34,-154.6 245.2,-145.3"/>
// <text xml:space="preserve" text-anchor="middle" x="318" y="-192.4" font-family="Times,serif" font-size="14.00">2</text>
// </g>
// <!-- 1&#45;&#45;2 -->
// <g id="edge10" class="edge">
// <title>1&#45;&#45;2</title>
// <path fill="none" stroke="black" stroke-dasharray="5,2" d="M441.29,-236.95C460.37,-240.26 487.23,-244 511,-244 511,-244 511,-244 707,-244 747.07,-244 778.18,-201.54 792.82,-177"/>
// <text xml:space="preserve" text-anchor="middle" x="609" y="-248.2" font-family="Times,serif" font-size="14.00">4</text>
// </g>
// <!--
title>
// <path fill="none" stroke="black" stroke-dasharray="5,2" d="M393.34,-242.96C386.1,-246.5 377.82,-250.23 370,-253 336.81,-264.76 324.63,-269.44 291,-259 227.56,-239.31 166.85,-186.05 139.76,-159.9"/>
// <text xml:space="preserve" text-anchor="middle" x="269.5" y="-256.06" font-family="Times,serif" font-size="14.00">6</text>
// </g>
// <!-- 1&#45;&#45;7 -->
// <g id="edge8" class="edge">
// <title>1&#45;&#45;7</title>
// <path fill="none" stroke="blue" stroke-width="2" d="M395.48,-219.02C381.87,-209.79 362.75,-197.44 345,-188.2 311.35,-170.68 270.34,-154.6 245.2,-145.3"/>
// <text xml:space="preserve" text-anchor="middle" x="318" y="-192.4" font-family="Times,serif" font-size="14.00">2</text>
// </g>
// <!-- 1&#45;&#45;2 -->
// <g id="edge10" class="edge">
// <title>1&#45;&#45;2</title>
// <path fill="none" stroke="black" stroke-dasharray="5,2" d="M441.29,-236.95C460.37,-240.26 487.23,-244 511,-244 511,-244 511,-244 707,-244 747.07,-244 778.18,-201.54 792.82,-177"/>
// <text xml:space="preserve" text-anchor="middle" x="609" y="-248.2" font-family="Times,serif" font-size="14.00">4</text>
// </g>
// <!-- 3 -->
// <g id="node7" class="node">
// <title>3</title>
// <ellipse fill="none" stroke="black" cx="512" cy="-198" rx="27" ry="18"/>
// <text xml:space="preserve" text-anchor="middle" x="512" y="-193.8" font-family="Times,serif" font-size="14.00">3</text>
// </g>
// <!-- 1&#45;&#45;3 -->
// <g id="edge11" class="edge">
// <title>1&#45;&#45;3</title>
// <path fill="none" stroke="black" stroke-dasharray="5,2" d="M437.74,-222.13C444.77,-219.09 452.66,-215.85 460,-213.2 468.52,-210.12 477.99,-207.17 486.43,-204.71"/>
// <text xml:space="preserve" text-anchor="middle" x="463.5" y="-217.4" font-family="Times,serif" font-size="14.00">3</text>
// </g>
// <!-- 2&#45;&#45;7 -->
// <g id="edge12" class="edge">
// <title>2&#45;&#45;7</title>
// <path fill="none" stroke="black" stroke-dasharray="5,2" d="M776.2,-157.31C710.27,-150.48 538.95,-133 513,-133 317,-133 317,-133 317,-133 293.72,-133 267.27,-134.21 248.2,-135.3"/>
// <text xml:space="preserve" text-anchor="middle" x="512" y="-137.2" font-family="Times,serif" font-size="14.00">3</text>
// </g>
// <!-- 2&#45;&#45;3 -->
// <g id="edge7" class="edge">
// <title>2&#45;&#45;3</title>
// <path fill="none" stroke="blue" stroke-width="2" d="M778.95,-168.34C772.27,-170.48 764.91,-172.58 758,-174 679.51,-190.14 584.57,-195.51 539.38,-197.23"/>
// <text xml:space="preserve" text-anchor="middle" x="657.5" y="-193.37" font-family="Times,serif" font-size="14.00">2</text>
// </g>
// <!-- 6 -->
// <g id="node8" class="node">
// <title>6</title>
// <ellipse fill="none" stroke="black" cx="609" cy="-110" rx="27" ry="18"/>
// <text xml:space="preserve" text-anchor="middle" x="609" y="-105.8" font-family="Times,serif" font-size="14.00">6</text>
// </g>
// <!-- 3&#45;&#45;6 -->
// <g id="edge14" class="edge">
// <title>3&#45;&#45;6</title>
// <path fill="none" stroke="black" stroke-dasharray="5,2" d="M528.69,-183.47C546.29,-167.16 574.68,-140.87 592.29,-124.55"/>
// <text xml:space="preserve" text-anchor="middle" x="560.5" y="-160.84" font-family="Times,serif" font-size="14.00">5</text>
// </g>
// <!-- 6&#45;&#45;4 -->
// <g id="edge16" class="edge">
// <title>6&#45;&#45;4</title>
// <path fill="none" stro
// ________________________________________________________________________________________________________________________
// testing 1 - 3, weight 3
// testing 2 - 7, weight 3
// testing 4 - 7, weight 4
// testing 0 - 4, weight 4
// testing 1 - 2, weight 4
// testing 6 - 2, weight 4
// connect 6 - 2
// <?xml version="1.0" encoding="UTF-8" standalone="no"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Generated by graphviz version 14.0.1 (0)
//  -->
// <!-- Title: G Pages: 1 -->
// <svg width="838pt" height="277pt"
//  viewBox="0.00 0.00 838.00 277.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 272.66)">
// <title>G</title>
// <polygon fill="white" stroke="none" points="-4,4 -4,-272.66 834,-272.66 834,4 -4,4"/>
// <!-- 4 -->
// <g id="node1" class="node">
// <title>4</title>
// <ellipse fill="none" stroke="black" cx="27" cy="-69" rx="27" ry="18"/>
// <text xml:space="preserve" text-anchor="middle" x="27" y="-64.8" font-family="Times,serif" font-size="14.00">4</text>
// </g>
// <!-- 5 -->
// <g id="node2" class="node">
// <title>5</title>
// <ellipse fill="none" stroke="black" cx="124" cy="-145" rx="27" ry="18"/>
// <text xml:space="preserve" text-anchor="middle" x="124" y="-140.8" font-family="Times,serif" font-size="14.00">5</text>
// </g>
// <!-- 4&#45;&#45;5 -->
// <g id="edge1" class="edge">
// <title>4&#45;&#45;5</title>
// <path fill="none" stroke="blue" stroke-width="2" d="M44.15,-82.89C52.41,-89.91 62.66,-98.51 72,-106 82.96,-114.79 95.48,-124.37 105.38,-131.84"/>
// <text xml:space="preserve" text-anchor="middle" x="75.5" y="-115.63" font-family="Times,serif" font-size="14.00">3</text>
// </g>
// <!-- 7 -->
// <g id="node3" class="node">
// <title>7</title>
// <ellipse fill="none" stroke="black" cx="221" cy="-137" rx="27" ry="18"/>
// <text xml:space="preserve" text-anchor="middle" x="221" y="-132.8" font-family="Times,serif" font-size="14.00">7</text>
// </g>
// <!-- 4&#45;&#45;7 -->
// <g id="edge2" class="edge">
// <title>4&#45;&#45;7</title>
// <path fill="none" stroke="black" stroke-dasharray="5,2" d="M53.49,-73.94C78.73,-79.23 118.24,-88.6 151,-101.2 168.13,-107.79 186.53,-117.48 200.02,-125.12"/>
// <text xml:space="preserve" text-anchor="middle" x="124" y="-105.4" font-family="Times,serif" font-size="14.00">4</text>
// </g>
// <!-- 5&#45;&#45;7 -->
// <g id="edge3" class="edge">
// <title>5&#45;&#45;7</title>
// <path fill="none" stroke="blue" stroke-width="2" d="M151.21,-142.79C164.5,-141.67 180.6,-140.32 193.87,-139.2"/>
// <text xml:space="preserve" text-anchor="middle" x="172.5" y="-145.44" font-family="Times,serif" font-size="14.00">2</text>
// </g>
// <!-- 8 -->
// <g id="node9" class="node">
// <title>8</title>
// <ellipse fill="none" stroke="black" cx="318" cy="-232" rx="27" ry="18"/>
// <text xml:space="preserve" text-anchor="middle" x="318" y="-227.8" font-family="Times,serif" font-size="14.00">8</text>
// </g>
// <!-- 7&#45;&#45;8 -->
// <g id="edge17" class="edge">
// <title>7&#45;&#45;8</title>
// <path fill="none" stroke="blue" stroke-width="2" d="M232.97,-153.09C241.33,-164.79 253.5,-180.67 266,-193 275.84,-202.71 288.11,-212.16 298.15,-219.33"/>
// <text xml:space="preserve" text-anchor="middle" x="269.5" y="-203.16" font-family="Times,serif" font-size="14.00">2</text>
// </g>
// <!-- 0 -->
// <g id="node4" class="node">
// <title>0</title>
// <ellipse fill="none" stroke="black" cx="706" cy="-58" rx="27" ry="18"/>
// <text xml:space="preserve" text-anchor="middle" x="706" y="-53.8" font-family="Times,serif" font-size="14.00">0</text>
// </g>
// <!-- 0&#45;&#45;4 -->
// <g id="edge6" class="edge">
// <title>0&#45;&#45;4</title>
// <path fill="none" stroke="black" stroke-dasharray="5,2" d="M691.16,-42.76C673.96,-25.58 642.85,0 610,0 123,0 123,0 123,0 87.33,0 56.03,-32.24 39.8,-52.65"/>
// <text xml:space="preserve" text-anchor="middle" x="366.5" y="-4.2" font-family="Times,serif" font-size="14.00">4</text>
// </g>
// <!-- 0&#45;&#45;7 -->
// <g id="edge4" class="edge">
// <title>0&#45;&#45;7</title>
// <path fill="none" stroke="blue" stroke-width="2" d="M678.82,-59.35C610.05,-63.39 419.05,-77.76 266,-119 258.51,-121.02 250.59,-123.98 243.56,-126.92"/>
// <text xml:space="preserve" text-anchor="middle" x="463.5" y="-85" font-family="Times,serif" font-size="14.00">1</text>
// </g>
// <!-- 2 -->
// <g id="node6" class="node">
// <title>2</title>
// <ellipse fill="none" stroke="black" cx="803" cy="-160" rx="27" ry="18"/>
// <text xml:space="preserve" text-anchor="middle" x="803" y="-155.8" font-family="Times,serif" font-size="14.00">2</text>
// </g>
// <!-- 0&#45;&#45;2 -->
// <g id="edge9" class="edge">
// <title>0&#45;&#45;2</title>
// <path fill="none" stroke="blue" stroke-width="2" d="M730.1,-66.49C739.53,-70.76 750.06,-76.66 758,-84.2 775.43,-100.76 788.11,-125.75 795.26,-142.46"/>
// <text xml:space="preserve" text-anchor="middle" x="754.5" y="-88.4" font-family="Times,serif" font-size="14.00">3</text>
// </g>
// <!-- 1 -->
// <g id="node5" class="node">
// <title>1</title>
// <ellipse fill="none" stroke="black" cx="415" cy="-232" rx="27" ry="18"/>
// <text xml:space="preserve" text-anchor="middle" x="415" y="-227.8" font-family="Times,serif" font-size="14.00">1</text>
// </g>
// <!-- 1&#45;&#45;5 -->
// <g id="edge5" class="edge">
// <title>1&#45;&#45;5</title>
// <path fill="none" stroke="black" stroke-dasharray="5,2" d="M393.34,-242.96C386.1,-246.5 377.82,-250.23 370,-253 336.81,-264.76 324.63,-269.44 291,-259 227.56,-239.31 166.85,-186.05 139.76,-159.9"/>
// <text xml:space="preserve" text-anchor="middle" x="269.5" y="-256.06" font-family="Times,serif" font-size="14.00">6</text>
// </g>
// <!-- 1&#45;&#45;7 -->
// <g id="edge8" class="edge">
// <title>1&#45;&#45;7</title>
// <path fill="none" stroke="blue" stroke-width="2" d="M395.48,-219.02C381.87,-209.79 362.75,-197.44 345,-188.2 311.35,-170.68 270.34,-154.6 245.2,-145.3"/>
// <text xml:space="preserve" text-anchor="middle" x="318" y="-192.4" font-family="Times,serif" font-size="14.00">2</text>
// </g>
// <!-- 1&#45;&#45;2 -->
// <g id="edge10" class="edge">
// <title>1&#45;&#45;2</title>
// <path fill="none" stroke="black" stroke-dasharray="5,2" d="M441.29,-236.95C460.37,-240.26 487.23,-244 511,-244 511,-244 511,-244 707,-244 747.07,-244 778.18,-201.54 792.82,-177"/>
// <text xml:space="preserve" text-anchor="middle" x="609" y="-248.2" font-family="Times,serif" font-size="14.00">4</text>
// </g>
// <!-- 3 -->
// <g id="node7" class="node">
// <title>3</title>
// <ellipse fill="none" stroke="black" cx="512" cy="-198" rx="27" ry="18"/>
// <text xml:space="preserve" text-anchor="middle" x="512" y="-193.8" font-family="Times,serif" font-size="14.00">3</text>
// </g>
// <!-- 1&#45;&#45;3 -->
// <g id="edge11" class="edge">
// <title>1&#45;&#45;3</title>
// <path fill="none" stroke="black" stroke-dasharray="5,2" d="M437.74,-222.13C444.77,-219.09 452.66,-215.85 460,-213.2 468.52,-210.12 477.99,-207.17 486.43,-204.71"/>
// <text xml:space="preserve" text-anchor="middle" x="463.5" y="-217.4" font-family="Times,serif" font-size="14.00">3</text>
// </g>
// <!-- 2&#45;&#45;7 -->
// <g id="edge12" class="edge">
// <title>2&#45;&#45;7</title>
// <path fill="none" stroke="black" stroke-dasharray="5,2" d="M776.2,-157.31C710.27,-150.48 538.95,-133 513,-133 317,-133 317,-133 317,-133 293.72,-133 267.27,-134.21 248.2,-135.3"/>
// <text xml:space="preserve" text-anchor="middle" x="512" y="-137.2" font-family="Times,serif" font-size="14.00">3</text>
// </g>
// <!-- 2&#45;&#45;3 -->
// <g id="edge7" class="edge">
// <title>2&#45;&#45;3</title>
// <path fill="none" stroke="blue" stroke-width="2" d="M778.95,-168.34C772.27,-170.48 764.91,-172.58 758,-174 679.51,-190.14 584.57,-195.51 539.38,-197.23"/>
// <text xml:space="preserve" text-anchor="middle" x="657.5" y="-193.37" font-family="Times,serif" font-size="14.00">2</text>
// </g>
// <!-- 6 -->
// <g id="node8" class="node">
// <title>6</title>
// <ellipse fill="none" stroke="black" cx="609" cy="-110" rx="27" ry="18"/>
// <text xml:space="preserve" text-anchor="middle" x="609" y="-105.8" font-family="Times,serif" font-size="14.00">6</text>
// </g>
// <!-- 3&#45;&#45;6 -->
// <g id="edge14" class="edge">
// <title>3&#45;&#45;6</title>
// <path fill="none" stroke="black" stroke-dasharray="5,2" d="M528.69,-183.47C546.29,-167.16 574.68,-140.87 592.29,-124.55"/>
// <text xml:space="preserve" text-anchor="middle" x="560.5" y="-160.84" font-family="Times,serif" font-size="14.00">5</text>
// </g>
// <!-- 6&#45;&#45;4 -->
// <g id="edge16" class="edge">
// <title>6&#45;&#45;4</title>
// <path fill="none" stro
// ________________________________________________________________________________________________________________________
// Set(8) {
//   [ 1, [ 0, 7 ] ],
//   [ 2, [ 5, 7 ] ],
//   [ 2, [ 2, 3 ] ],
//   [ 2, [ 1, 7 ] ],
//   [ 2, [ 7, 8 ] ],
//   [ 3, [ 4, 5 ] ],
//   [ 3, [ 0, 2 ] ],
//   [ 4, [ 6, 2 ] ]
// }
// graph G {
//   rankdir=LR;
//   4;
//   5;
//   7;
//   0;
//   1;
//   2;
//   3;
//   6;
//   8;
//   4 -- 5 [label="3", color="blue", penwidth=2];
//   4 -- 7 [label="4", style="dashed"];
//   5 -- 7 [label="2", color="blue", penwidth=2];
//   0 -- 7 [label="1", color="blue", penwidth=2];
//   1 -- 5 [label="6", style="dashed"];
//   0 -- 4 [label="4", style="dashed"];
//   2 -- 3 [label="2", color="blue", penwidth=2];
//   1 -- 7 [label="2", color="blue", penwidth=2];
//   0 -- 2 [label="3", color="blue", penwidth=2];
//   1 -- 2 [label="4", style="dashed"];
//   1 -- 3 [label="3", style="dashed"];
//   2 -- 7 [label="3", style="dashed"];
//   6 -- 2 [label="4", color="blue", penwidth=2];
//   3 -- 6 [label="5", style="dashed"];
//   6 -- 0 [label="6", style="dashed"];
//   6 -- 4 [label="7", style="dashed"];
//   7 -- 8 [label="2", color="blue", penwidth=2];
//   8 -- 1 [label="5", style="dashed"];
// }

// %%
MST = demoFile('tiny.txt')
MST
